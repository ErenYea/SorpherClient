# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome import options
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument("window-size=1200x600")
# options.headless = True
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--start-maximized")
# options.headless = False
# options.add_argument("window-size=1200x600")
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
# options.headless = False
options.add_argument("--disable-infobars")
# options.add_argument("start-maximized")
options.add_argument("--disable-extensions")    
# options.add_argument("window-size=1200x600")
options.add_argument("test-type")
options.add_argument('--disable-useAutomationExtension')
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
options.add_argument("--disable-xss-auditor")
options.add_argument("--disable-web-security")
options.add_argument("--allow-running-insecure-content")
options.add_argument("--disable-setuid-sandbox")
options.add_argument("--disable-webgl")
options.add_argument("--disable-popup-blocking")
options.add_argument("no-default-browser-check")
options.add_argument("--disable-notifications")

driver = webdriver.Chrome(chrome_options=options)



a = ActionChains(driver)

driver.get("https://www.attheraces.com/racecard/Plumpton/21-March-2022/1355")
driver.implicitly_wait(30)
# driver.maximize_window()

interested_courses = ['Ascot','Bangor-on-dee','Bath','Brighton','Chepstow','Chester','Doncaster','Fakenham','Ffos las','Fontwell','Hereford','Hexham','Lingfield','Newcastle','Newton abbot','Plumpton','Ripon','Sedgefield','Southwell','Uttoxeter','Windsor','Wolverhampton','Worcester','Yarmouth']
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_21752\1318402301.py:41: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [2], in <cell line: 41>()
#      38 options.add_argument("no-default-browser-check")
#      39 options.add_argument("--disable-notifications")
# ---> 41 driver = webdriver.Chrome(chrome_options=options)
#      45 a = ActionChains(driver)
#      47 driver.get("https://www.attheraces.com/racecard/Plumpton/21-March-2022/1355")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py:70, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67 if not service:
# ...

# %%
date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
date_input.click()
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\1576243947.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")

# %%
value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
select_month.select_by_visible_text(value1)

value2 = driver.find_element_by_xpath("//table[@class='pika-table']/tbody/tr/td[3]/button").click()
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3775335842.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3775335842.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3775335842.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3775335842.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
a.move_to_element(date_input).perform()
# time.sleep(3)

# %%
race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\2632651791.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

# %%
race_courses
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d326e1ddf9cd201c289d04aeca8e94cd", element="0c922007-b85d-4a97-b817-74de5e6c8120")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d326e1ddf9cd201c289d04aeca8e94cd", element="d0656876-fb5e-403b-bc42-822624cacfb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d326e1ddf9cd201c289d04aeca8e94cd", element="a977ae44-1748-4ec6-a0bc-21017a3e803e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d326e1ddf9cd201c289d04aeca8e94cd", element="f47da29b-8a8f-4f33-84a8-49396ab75eb8")>]

# %%
data = []
for i,race_course in enumerate(race_courses):
    
    races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
    for k in races:
        print(k.find_element_by_tag_name('a').get_attribute('href'))
        data.append(k.find_element_by_tag_name('a').get_attribute('href'))
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\1101302991.py:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
# C:\Users\alikh\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# https://www.attheraces.com/racecard/Kempton/02-March-2022/1700
# https://www.attheraces.com/racecard/Kempton/02-March-2022/1730
# https://www.attheraces.com/racecard/Kempton/02-March-2022/1800
# https://www.attheraces.com/racecard/Kempton/02-March-2022/1830
# https://www.attheraces.com/racecard/Kempton/02-March-2022/1900
# https://www.attheraces.com/racecard/Kempton/02-March-2022/1930
# ...

# %%
driver.get('https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/1830')

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument("window-size=1200x600")
options.headless = True
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--start-maximized")
# options.headless = False
# options.add_argument("window-size=1200x600")
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
# options.headless = False
options.add_argument("--disable-infobars")
# options.add_argument("start-maximized")
options.add_argument("--disable-extensions")    
# options.add_argument("window-size=1200x600")
options.add_argument("test-type")
options.add_argument('--disable-useAutomationExtension')
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
options.add_argument("--disable-xss-auditor")
options.add_argument("--disable-web-security")
options.add_argument("--allow-running-insecure-content")
options.add_argument("--disable-setuid-sandbox")
options.add_argument("--disable-webgl")
options.add_argument("--disable-popup-blocking")
options.add_argument("no-default-browser-check")
options.add_argument("--disable-notifications")


driver = webdriver.Chrome(options=options)

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.support.ui import Select

a = ActionChains(driver)

driver.get("https://www.attheraces.com/results")
driver.implicitly_wait(10)
driver.maximize_window()

interested_courses = ['Ascot','Bangor-on-dee','Bath','Brighton','Chepstow','Chester','Doncaster','Fakenham','Ffos las','Fontwell','Hereford','Hexham','Lingfield','Newcastle','Newton abbot','Plumpton','Ripon','Sedgefield','Southwell','Uttoxeter','Windsor','Wolverhampton','Worcester','Yarmouth']


time.sleep(3)
data = []
for day in range(15):
    
    if (day==0):
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
        
    else:
        race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

        for i,race_course in enumerate(race_courses):
            

                course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text

                if course_name.strip() in interested_courses:

                    races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
                    

                    for j,rac in enumerate(races):
                        race = rac.find_element_by_tag_name('a').get_attribute('href')
                        print(race)
                        data.append(race)

        driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)
        
        date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
        a.move_to_element(date_input).perform()
        
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
        

print(data)
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\689326813.py:58: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [58], in <cell line: 55>()
#      55 for day in range(15):
#      57     if (day==0):
# ---> 58         previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
#      59         previous.click()
#      61         time.sleep(2)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:520, in WebDriver.find_element_by_xpath(self, xpath)
#     498 """
#     499 Finds an element by xpath.
#     500
#    (...)
# ...

# %%
sectional_times.click()

# %%
data.index(j)
# Out:
# 8

# %%
import pygsheets
def write_to_gsheet(service_file_path, spreadsheet_id, sheet_name, data_df):
    """
    this function takes data_df and writes it under spreadsheet_id
    and sheet_name using your credentials under service_file_path
    """
    gc = pygsheets.authorize(service_file=service_file_path)
    sh = gc.open_by_key(spreadsheet_id)
    try:
        sh.add_worksheet(sheet_name)
    except:
        pass
    wks_write = sh.worksheet_by_title(sheet_name)
    wks_write.clear('A1',None,'*')
    wks_write.set_dataframe(data_df, (1,1), encoding='utf-8', fit=True)
    wks_write.frozen_rows = 1
a = ActionChains(driver)
def get_min(ss):
    mins = 0
    for i in ss:
        print(i)
        for k in ss[i]:
            print(ss[i][k])
            if type(ss[i][k]) == type({}):
                print('ha')
                if mins < len(ss[i][k]['Times']):
                    mins=len(ss[i][k]['Times'])
    return mins
                
driver.get("https://www.attheraces.com/results")
driver.implicitly_wait(10)
driver.maximize_window()

interested_courses = ['ascot','bangor-on-dee','bath','brighton','chepstow','chester','doncaster','fakenham','ffos las','fontwell','hereford','hexham','lingfield','newcastle','newton abbot','plumpton','ripon','sedgefield','southwell','uttoxeter','windsor','wolverhampton','worcester','yarmouth']

time.sleep(3)
data = []
for day in range(15):
    
    if (day==0):
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
        
    else:
        race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

        for i,race_course in enumerate(race_courses):
            

            course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text.lower().strip()

            if course_name in interested_courses:

                races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")


                for j,rac in enumerate(races):
                    race = rac.find_element_by_tag_name('a').get_attribute('href')
                    print(race)
                    data.append(race)

    driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)

    date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
    a.move_to_element(date_input).perform()

    previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
    previous.click()

    time.sleep(2)

print(data)

comp_data = []
ss = {}
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3997285396.py:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3997285396.py:64: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3997285396.py:66: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3997285396.py:69: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
comp_data = []
ss = {}

# %%
import datefinder,re

# %%
sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\513907259.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:520, in WebDriver.find_element_by_xpath(self, xpath)
#     498 """
#     499 Finds an element by xpath.
#     500
#    (...)
#     513         element = driver.find_element_by_xpath('//div/td[1]')
#     514 """
#     515 warnings.warn(
# ...

# %%
lin = []
for link in data:
    driver.get(link)
    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
    if 'Sectional Times' in sectional_times.text:
        
     
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()
#         sectional_times.click()
        race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
        details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
        matches = datefinder.find_dates(driver.find_element_by_xpath("//h2[@class='h4 flush']").text)
        c = 0
        for match in matches:
            if c==0:
                c+=1
                continue
            date = f'{match.day}/{match.month}/{match.year}'
#         racecourse_name = details1[1]
        ress = re.findall('\d+ [A-Za-z]+ \d+|\d+ [A-Za-z]+ [A-Za-z]+ \d+',driver.find_element_by_xpath("//h2[@class='h4 flush']").text)
        racecourse_name = ''
        for i in ress[0].split(' '):
            if i.isdigit():
                continue
            else:
                racecourse_name += i+' '
#                 print(i)
    #         date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
        print(racecourse_name)
        print(race_time)
        print(date)
        total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
        all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')
        time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text
        all_colu = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"]')
#         print(time_name_date)
        length_of_columns = len(driver.find_elements_by_xpath('//div[@class="scrollbar__content-wrapper js-scrollbar__content-wrapper"]/div/div[@class="card-header"]/div/div'))
        mm = {}
        mm['date'] = date
        mm['course_name'] = racecourse_name
        mm['race_time']=race_time
        for i,j in enumerate(all_times):

            horse = driver.find_element_by_xpath(f'//div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div[3]/div/div/h2/a').text
            print(horse)
            inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
            inner_list = []
            for k in inner_ele:
                if 'is-hidden' in k.get_attribute('class'):
                    continue
                if length_of_columns > 9:
                    if k.text == '':
        
                        horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                        slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')
                        ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                        print(k.text)
                        if 'm' in k.text:
                            times = k.text
                            
                            minutes = float(times.split('\n')[0].split(' ')[0].replace('m',''))
                            if 's' in times:
                                seconds = float(times.split('\n')[0].split(' ')[1].replace('s',''))
                                conv_time = round((minutes*60+seconds),2)
                                print(conv_time)
                            else:
                                conv_time = round((minutes*60),2)
                                print(conv_time)
                        else:
                            inner_list.append(k.text.split('\n')[0])
                        horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                        slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')
                        ActionChains(driver).click_and_hold(slider).move_by_offset(-horizontal_bar_width/2, 0).release().perform()

                    else:
                        print(k.text)
                        if 'm' in k.text:
                            times = k.text
                            
                            minutes = float(times.split('\n')[0].split(' ')[0].replace('m',''))
                            if 's' in times:
                                seconds = float(times.split('\n')[0].split(' ')[1].replace('s',''))
                                conv_time = round((minutes*60+seconds),2)
                                print(conv_time)
                            else:
                                conv_time = round((minutes*60),2)
                                print(conv_time)
                        else:
                            inner_list.append(k.text.split('\n')[0])
                else:
                    print(k.text)
                print('///////////////////////////////')
            mm[horse] = {'Finish':conv_time,'Times':inner_list} 
        #             print('\n')
        ss[link] = mm
        print('Sectional Times')
        print('*********************************')
#     lin.append(sectional_times)
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3053716704.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3053716704.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3053716704.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3053716704.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
ss
# Out:
# {'https://www.attheraces.com/racecard/Ascot/27-March-2022/1300': {'date': '27/3/2022',
#   'course_name': 'Ascot ',
#   'race_time': '13:00',
#   'FIFTY BALL': {'Finish': 325.47,
#    'Times': ['88.28',
#     '62.18',
#     '57.30',
#     '29.73',
#     '28.93',
#     '29.00',
#     '14.96',
#     '15.10']},
#   'SIZABLE SAM': {'Finish': 326.39,
#    'Times': ['88.01',
#     '62.09',
#     '57.50',
#     '29.58',
#     '29.08',
#     '28.98',
#     '15.19',
#     '15.95']},
#   'KILGANER QUEEN': {'Finish': 326.79,
#    'Times': ['88.50',
#     '62.51',
#     '57.30',
#     '29.53',
#     '29.49',
#     '28.77',
#     '15.18',
#     '15.50']},
#   'SAINT SONNET': {'Finish': 328.38,
#    'Times': ['88.06',
#     '62.24',
#     '57.29',
#     '29.62',
#     '29.01',
#     '29.62',
#     '16.06',
#     '16.47']}},
#  'https://www.attheraces.com/racecard/Ascot/27-March-2022/1410': {'date': '27/3/2022',
#   'course_name': 'Ascot ',
#   'race_time': '14:10'},
# ...

# %%
inner_ele[-1].text
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 inner_ele[-1].text
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:77, in WebElement.text(self)
#      74 @property
#      75 def text(self) -> str:
#      76     """The text of the element."""
# ---> 77     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:710, in WebElement._execute(self, command, params)
#     708     params = {}
#     709 params['id'] = self._id
# --> 710 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:424, in WebDriver.execute(self, driver_command, params)
#     422 response = self.command_executor.execute(driver_command, params)
#     423 if response:
# ...

# %%
from bs4 import BeautifulSoup 
import requests

# %%
url = 'https://www.attheraces.com/racecard/Hereford/25-March-2022/1335'
req = requests.get(url)

# %%
soup = BeautifulSoup(req.text,"html.parser")
print(soup)
# Out:
# <html><head>
# <title>ERROR: The client request can not be fulfilled</title>
# </head><body>
# <h1>ERROR: (Forbidden)</h1>
# <hr/>
# <p>We were unable to satisfy your request due to access control:
# <p>Unauthorized
# </p></p></body></html>

# %%
total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')
time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text
all_colu = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"]')
print(time_name_date)
length_of_columns = len(driver.find_elements_by_xpath('//div[@class="scrollbar__content-wrapper js-scrollbar__content-wrapper"]/div/div[@class="card-header"]/div/div'))
for i,j in enumerate(all_times):

    horse = driver.find_element_by_xpath(f'//div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div[3]/div/div/h2/a').text
    print(horse)
    inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
    for k in inner_ele:
        if 'is-hidden' in k.get_attribute('class'):
            continue
        if length_of_columns > 9:
            if k.text == '':

                horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')
                ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                print(k.text)
                horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')
                ActionChains(driver).click_and_hold(slider).move_by_offset(-horizontal_bar_width/2, 0).release().perform()

            else:
                print(k.text)
        else:
            print(k.text)
        print('///////////////////////////////')

#             print('\n')
print('Sectional Times')
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3310693250.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3310693250.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\3310693250.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text
# ...

# %%
inner_ele[0].text
# Out:
# ''

# %%
driver.get(data[8])

# %%
driver.fin

# %%
length_of_columns = len(driver.find_elements_by_xpath('//div[@class="scrollbar__content-wrapper js-scrollbar__content-wrapper"]/div/div[@class="card-header"]/div/div'))
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15692\2613237382.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   len(driver.find_elements_by_xpath('//div[@class="scrollbar__content-wrapper js-scrollbar__content-wrapper"]/div/div[@class="card-header"]/div/div'))
# 14

# %%
lin[8]
# Out:
# 'https://www.attheraces.com/ajax/sectionals/1259060/times?page=/racecard/Lingfield/02-March-2022/1230&raceid=1259060'

# %%
all_columns = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-header"]/div[@class="card-section"]/div')
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15456\3111508924.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_columns = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-header"]/div[@class="card-section"]/div')

# %%
horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_848/3662658816.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']

# %%
slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_848/3188179515.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')

# %%
ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()

# %%
ActionChains(driver).click_and_hold(slider).move_by_offset(0, 0).release().perform()

# %%
col = 0
for i in all_columns:
    if all_columns.index(i) <=2 :
        continue
    if i.text == '':
        ele =  driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
        desired_y = (ele.size['height'] / 2) +ele.location['y']
        window_h = driver.execute_script('return window.innerHeight')
        window_y = driver.execute_script('return window.pageYOffset')
        current_y = (window_h / 2) + window_y
        scroll_y_by = desired_y - current_y
        driver.execute_script("window.scrollBy(0, arguments[0]);", scroll_y_by)
        horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
        slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
        ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
        
    ele =  i
    desired_y = (ele.size['height'] / 2) +ele.location['y']
    window_h = driver.execute_script('return window.innerHeight')
    window_y = driver.execute_script('return window.pageYOffset')
    current_y = (window_h / 2) + window_y
    scroll_y_by = desired_y - current_y
    driver.execute_script("window.scrollBy(0, arguments[0]);", scroll_y_by)
    if i.text == 'Finish':
        print('ok')
    print(i.text)
    col += 1
# Out:
# Start-9f
# 9f-8f
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15456\3088490218.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ele =  driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15456\3088490218.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
# C:\Users\alikh\AppData\Local\Temp\ipykernel_15456\3088490218.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
# ok
# Finish

# %%
col
# Out:
# 11

# %%
all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_848/2792596782.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')

# %%
len(all_times)
# Out:
# 11

# %%
time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_7016/3871369868.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text

# %%
all_colu = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"]')
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_7016/3106612382.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_colu = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"]')

# %%
for i,j in enumerate(all_colu):
    inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
    for k in inner_ele:
        if k.text == '':
            continue
        print(k.text)
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_7016/296463245.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
# 15.63
# 12.97
# 12.37
# 12.36
# 12.33
# 13.11
# 12.09
# 11.45
# 11.25
# FRONT
# 11.74
# FRONT
# 15.81
# 13.09
# 12.38
# 12.26
# 12.21
# 12.99
# 12.41
# 11.44
# 11.51
# 11.42
# 15.14
# 12.81
# 12.51
# 12.32
# 12.51
# 13.00
# 12.14
# 11.57
# 11.70
# 11.96
# 15.44
# 13.04
# 12.37
# 12.33
# 12.39
# 13.02
# 12.24
# 11.61
# 11.55
# 11.84
# 15.02
# 12.81
# 12.47
# 12.27
# 12.51
# 12.96
# 12.24
# 11.52
# FRONT
# 11.85
# FRONT
# 12.24
# 14.76
# FRONT
# 12.89
# FRONT
# 12.44
# FRONT
# 12.24
# FRONT
# 12.50
# FRONT
# 13.01
# FRONT
# 12.28
# FRONT
# 11.64
# FRONT
# 12.00
# 12.13
# 15.37
# 13.05
# 12.40
# 12.26
# 12.47
# 13.07
# 12.07
# 11.55
# 11.62
# 12.06
# ...

# %%
for i,j in enumerate(all_times):
    horse = driver.find_element_by_xpath(f'//div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div[3]/div/div/h2/a').text
    print(horse)
    inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
    for k in inner_ele:
        if k.text == '':
            continue
        print(k.text)
    print('\n')
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_7016/7817279.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horse = driver.find_element_by_xpath(f'//div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div[3]/div/div/h2/a').text
# C:\Users\alikh\AppData\Local\Temp/ipykernel_7016/7817279.py:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
# DOONBEG FARMER
# 15.63
# 12.97
# 12.37
# 12.36
# 12.33
# 13.11
# 12.09
# 11.45
# 11.25
# FRONT
# 11.74
# FRONT
#
#
# NO SUCH LUCK
# 15.81
# 13.09
# 12.38
# 12.26
# 12.21
# 12.99
# 12.41
# 11.44
# 11.51
# 11.42
#
#
# SHERPA TRAIL
# 15.14
# 12.81
# 12.51
# 12.32
# 12.51
# 13.00
# 12.14
# 11.57
# 11.70
# 11.96
#
#
# LAKE SAND
# 15.44
# 13.04
# 12.37
# 12.33
# 12.39
# ...

# %%
driver.find_element_by_xpath('//div[@class="card-body"]/div[@class="card-entry"][1]/div/div[3]/div/div/h2/a').text
# Out:
# C:\Users\alikh\AppData\Local\Temp/ipykernel_7016/4207880207.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//div[@class="card-body"]/div[@class="card-entry"][1]/div/div[3]/div/div/h2/a').text
# 'DOONBEG FARMER'

# %%
race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

for i,race_course in enumerate(race_courses):
    if (i>=1):
        
        course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]").text
        
        if course_name.strip() in interested_courses:
        
            races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
            data = []
            
            for j,rac in enumerate(races):
                try:
                    race = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li[{j+1}]/a").get_attribute('href')
                    print(race)
                    driver.get(race)
                    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a").get_attribute('href')
                    driver.get(sectional_times)
                    driver.refresh()

                    total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]

                    for k in range(int(total_runners)):
                        horse_name = driver.find_element_by_xpath(f"//div[@class='card-body']/div[{k+1}]/div/div[3]/div/div/h2/a")   
                        print(horse_name.text)
                    print('Sectional Times')
                    driver.back()
                except:
                    continue
            print(len(races))
            print(course_name)
