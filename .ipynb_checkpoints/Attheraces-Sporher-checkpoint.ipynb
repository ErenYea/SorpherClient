# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains

driver = webdriver.Chrome(r"C:\Users\USER\Documents\Scraping_waghera\chromedriver.exe")

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.support.ui import Select

a = ActionChains(driver)

driver.get("https://www.attheraces.com/results")
driver.implicitly_wait(10)
driver.maximize_window()

interested_courses = ['Ascot','Bangor-on-dee','Bath','Brighton','Chepstow','Chester','Doncaster','Fakenham','Ffos las','Fontwell','Hereford','Hexham','Lingfield','Newcastle','Newton abbot','Plumpton','Ripon','Sedgefield','Southwell','Uttoxeter','Windsor','Wolverhampton','Worcester','Yarmouth']

date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
date_input.click()

value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
select_month.select_by_visible_text(value1)

value2 = driver.find_element_by_xpath("//table[@class='pika-table']/tbody/tr/td[7]/button").click()

a.move_to_element(date_input).perform()
time.sleep(3)

race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

for i,race_course in enumerate(race_courses):
    if (i>=1):
        
        course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]").text
        
        if course_name.strip() in interested_courses:
        
            races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
            data = []
            
            for j,rac in enumerate(races):
                race = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li[{j+1}]/a").get_attribute('href')
                print(race)
                driver.get(race)
                
                WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()
                
                total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
                for k in range(len(total_rows)):
                    
                    horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a")   
                    print(horse_name.text)
                    
                    all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
                    print(len(all_time))
                    for s in range(len(all_time)):
                        if s<(len(all_time)-3):
                            times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
                            print(times.text.split('\n')[0])
                            if (s == (len(all_time)-4)):
                                horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                                slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
                                ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                                time.sleep(2)
                                minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
                                seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
                                conv_time = round((minutes*60+seconds),2)
                                print(conv_time)
                            
                    all_columns = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[@class='card-header']/div/div")
                    print(len(all_columns))
                    for m in range(len(all_columns)):
                        if m<(len(all_columns)-3):
                            column = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[1]/div/div[{m+4}]")
                            print(column.text)    
                            
                race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
                details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
                racecourse_name = details1[1]
                date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
                print(racecourse_name)
                print(race_time)
                print(date)
                print('Sectional Times')
                print("-------------------------------------------------------------")
            print(len(races))
            print(course_name)
# Out:
# <ipython-input-5-8e4f28af59aa>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\USER\Documents\Scraping_waghera\chromedriver.exe")

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains

driver = webdriver.Chrome(r"C:\Users\USER\Documents\Scraping_waghera\chromedriver.exe")

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.support.ui import Select

a = ActionChains(driver)

driver.get("https://www.attheraces.com/results")
driver.implicitly_wait(10)
driver.maximize_window()

interested_courses = ['Ascot','Bangor-on-dee','Bath','Brighton','Chepstow','Chester','Doncaster','Fakenham','Ffos las','Fontwell','Hereford','Hexham','Lingfield','Newcastle','Newton abbot','Plumpton','Ripon','Sedgefield','Southwell','Uttoxeter','Windsor','Wolverhampton','Worcester','Yarmouth']

# date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
# date_input.click()

# value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
# select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
# driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
# select_month.select_by_visible_text(value1)

# value2 = driver.find_element_by_xpath("//table[@class='pika-table']/tbody/tr/td[7]/button").click()

# a.move_to_element(date_input).perform()
time.sleep(3)

for day in range(15):
    
    if (day==0):
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
        
    else:
        race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

        for i,race_course in enumerate(race_courses):
            if (i>=1):

                course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]").text

                if course_name.strip() in interested_courses:

                    races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
                    data = []

                    for j,rac in enumerate(races):
                        race = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li[{j+1}]/a").get_attribute('href')
                        print(race)
                        driver.get(race)
                        
                        sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
                        if 'Sectional Times' in sectional_times.text:
                        
                            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()

                            total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
                            for k in range(len(total_rows)):

                                horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a")   
                                print(horse_name.text)

                                all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
                                print(len(all_time))
                                for s in range(len(all_time)):
                                    if s<(len(all_time)-3):
                                        times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
                                        print(times.text.split('\n')[0])
                                        if (s == (len(all_time)-4)):
                                            horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                                            slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
                                            ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                                            time.sleep(2)
                                            minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
                                            seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
                                            conv_time = round((minutes*60+seconds),2)
                                            print(conv_time)

                                all_columns = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[@class='card-header']/div/div")
                                print(len(all_columns))
                                for m in range(len(all_columns)):
                                    if m<(len(all_columns)-3):
                                        column = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[1]/div/div[{m+4}]")
                                        print(column.text)    

                            race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
                            details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
                            racecourse_name = details1[1]
                            date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
                            print(racecourse_name)
                            print(race_time)
                            print(date)
                            print('Sectional Times')
                            print("-------------------------------------------------------------")
                        print(len(races))
                        print(course_name)
                    
        driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)
        
        date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
        a.move_to_element(date_input).perform()
        
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
# Out:
# <ipython-input-8-17de5232cc5e>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\USER\Documents\Scraping_waghera\chromedriver.exe")
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1400
# 7
# Chepstow
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1430
# 7
# Chepstow
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1505
# 7
# Chepstow
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1535
# 7
# Chepstow
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1610
# 7
# Chepstow
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1645
# 7
# Chepstow
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1715
# 7
# Chepstow
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1358
#
# 11
#
# 59.50
# 30.48
# 29.28
# 27.12
# 14.20
# 14.88
# 4m 4.55s
# 244.55
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# ROYLE STEEL
# 11
# 69.33
# 59.70
# 30.45
# 29.06
# 27.19
# 14.62
# 15.56
# 4m 5.92s
# 245.92
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BALKALIN
# 11
# 68.86
# 59.62
# 30.06
# 29.00
# 28.14
# 15.03
# 15.85
# 4m 6.56s
# 246.56
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# PEPITE FLEURIE
# 11
# 68.60
# 59.38
# 30.34
# 29.27
# 30.59
# 17.63
# 17.86
# 4m 13.67s
# 253.67
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 13:58
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# Newcastle
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1433
#
# 12
# 66.10
# 65.00
# 59.32
# 30.38
# 30.92
# 28.92
# 15.40
# 16.04
#
# 312.09
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# DAWN RAIDER
# 12
#
# 65.01
# 59.49
# 30.17
# 30.98
# 29.62
# 15.28
# 15.48
# 5m 12.34s
# 312.34
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CRACKING FIND
# 12
#
# 65.30
# 59.49
# 30.42
# 30.89
# 29.55
# 15.55
# 16.19
# 5m 12.92s
# 312.92
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SIX ONE NINE
# 12
#
# 65.34
# 59.44
# 30.54
# 30.94
# 29.94
# 15.60
# 17.19
# 5m 14.21s
# 314.21
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BROOMFIELDS KAN
# 12
#
# 64.62
# 59.56
# 30.39
# 30.93
# 29.46
# 16.80
# 17.56
# 5m 15.28s
# 315.28
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SPIDER'S BITE
# 12
#
# 64.79
# 59.45
# 30.65
# 31.11
# 31.48
# 16.07
# 17.02
# 5m 16.80s
# 316.8
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# LASTIN' MEMORIES
# 12
#
# 64.49
# 59.69
# 30.48
# 31.09
# 32.17
# 16.28
# 19.21
# 5m 20.11s
# 320.11
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SHAWS BRIDGE
# 12
#
# 64.85
# 59.73
# 29.90
# 31.26
# 32.52
# 18.24
# 21.32
# 5m 24.40s
# 324.4
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 14:33
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# Newcastle
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1510
#
# 11
# 63.98
# 57.65
# 28.89
# 28.39
# 27.40
# 14.70
# 14.71
# 3m 55.73s
# 235.73
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SAINT ARVANS
# 11
# 63.96
# 57.80
# 28.89
# 28.42
# 27.65
# 14.61
# 14.96
# 3m 56.31s
# 236.31
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THEATRE LEGEND
# 11
# 63.46
# 57.80
# 28.76
# 28.59
# 27.65
# 15.14
# 16.76
# 3m 58.16s
# 238.16
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MINELLA PLUS
# 11
# 63.72
# 57.78
# 28.91
# 28.46
# 28.54
# 16.73
# 17.99
# 4m 2.11s
# 242.11
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 15:10
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# Newcastle
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1543
#
# 12
# 95.98
# 61.07
# 58.48
# 28.88
# 28.59
# 27.47
# 14.26
# 14.81
#
# 329.54
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# JETOILE
# 12
#
# 60.97
# 58.17
# 28.96
# 28.35
# 27.58
# 14.72
# 15.92
# 5m 31.01s
# 331.01
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KAYF HERNANDO
# 12
#
# 61.20
# 58.34
# 29.08
# 28.48
# 28.14
# 15.34
# 16.16
# 5m 32.51s
# 332.51
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RAFFERTY'S RETURN
# 12
#
# 61.06
# 58.46
# 29.09
# 28.49
# 28.03
# 16.52
# 17.56
# 5m 34.80s
# 334.8
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 15:43
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# Newcastle
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1618
#
# 12
# 119.14
# 64.36
# 61.13
# 30.87
# 30.91
# 29.93
# 15.08
# 16.39
#
# 367.81
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RAPID RAIDER
# 12
#
# 64.51
# 61.28
# 30.71
# 30.85
# 29.76
# 15.81
# 16.17
# 6m 7.87s
# 367.87
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CHASE THE WIND
# 12
#
# 64.54
# 61.29
# 30.90
# 30.81
# 30.36
# 15.57
# 16.16
# 6m 7.94s
# 367.94
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MORNINGSIDE
# 12
#
# 64.33
# 61.23
# 30.84
# 30.88
# 30.28
# 15.76
# 16.04
# 6m 8.73s
# 368.73
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GUN MERCHANT
# 12
#
# 64.58
# 61.39
# 30.89
# 30.75
# 31.21
# 15.75
# 16.97
# 6m 9.75s
# 369.75
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SHANBALLY ROSE
# 12
#
# 64.56
# 61.21
# 30.99
# 31.07
# 32.20
# 16.71
# 19.29
# 6m 14.58s
# 374.58
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 16:18
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# Newcastle
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1650
#
# 12
# 66.31
# 60.79
# 58.96
# 30.45
# 30.45
# 27.67
# 13.88
# 13.58
#
# 302.07
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KINONDO KWETU
# 12
#
# 61.16
# 58.89
# 30.53
# 30.54
# 27.74
# 13.90
# 14.05
# 5m 2.59s
# 302.59
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KAJAKI
# 12
#
# 61.09
# 59.04
# 30.49
# 30.46
# 27.89
# 13.78
# 14.21
# 5m 2.65s
# 302.65
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THEOCRAT
# 12
#
# 60.86
# 58.85
# 30.53
# 30.19
# 27.93
# 13.88
# 13.97
# 5m 2.77s
# 302.77
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# IDILICO
# 12
#
# 60.89
# 59.07
# 30.46
# 30.46
# 27.86
# 14.59
# 14.88
# 5m 4.35s
# 304.35
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# DUTY CALLS
# 12
#
# 60.84
# 59.00
# 30.34
# 30.59
# 28.00
# 14.35
# 16.64
# 5m 5.61s
# 305.61
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BEACH BREAK
# 12
#
# 61.11
# 59.13
# 30.42
# 30.56
# 27.91
# 14.60
# 16.58
# 5m 5.64s
# 305.64
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CURRAMORE
# 12
#
# 61.66
# 58.22
# 30.41
# 30.18
# 28.28
# 15.58
# 14.99
# 5m 6.02s
# 306.02
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BAK ROCKY
# 12
#
# 61.10
# 59.19
# 30.43
# 30.62
# 28.87
# 15.59
# 16.19
# 5m 7.24s
# 307.24
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 16:50
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# Newcastle
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1725
#
# 11
# 63.03
# 60.66
# 28.79
# 28.41
# 25.87
# 13.03
# 13.75
# 3m 53.54s
# 233.54
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KNOCKANORE
# 11
# 64.51
# 59.83
# 28.72
# 28.07
# 25.73
# 12.90
# 13.79
# 3m 53.55s
# 233.55
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# NINETOFIVE
# 11
# 63.65
# 60.20
# 28.83
# 28.20
# 25.94
# 13.49
# 14.46
# 3m 54.77s
# 234.77
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# HIDALGO DE L'ISLE
# 11
# 64.51
# 59.61
# 28.93
# 28.14
# 25.70
# 13.34
# 14.60
# 3m 54.84s
# 234.84
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CHASE A FORTUNE
# 11
# 65.48
# 59.66
# 28.81
# 27.67
# 26.31
# 13.89
# 14.53
# 3m 56.34s
# 236.34
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BLAME THE FARRIER
# 11
# 65.27
# 59.49
# 28.91
# 27.67
# 26.18
# 14.02
# 15.84
# 3m 57.37s
# 237.37
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BEING TED
# 11
# 65.16
# 59.50
# 28.70
# 28.14
# 26.37
# 14.39
# 15.89
# 3m 58.16s
# 238.16
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BRAY DALE
# 11
# 64.28
# 59.91
# 28.87
# 28.19
# 27.05
# 14.49
# 15.38
# 3m 58.16s
# 238.16
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# WADMAL
# 11
# 64.36
# 59.76
# 28.93
# 28.18
# 29.06
# 16.83
# 19.00
# 4m 6.11s
# 246.11
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 17:25
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# Newcastle
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-8-17de5232cc5e> in <module>
#     109
#     110         date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
# --> 111         a.move_to_element(date_input).perform()
#     112
#     113         previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\action_chains.py in perform(self)
#      73         Performs all stored actions.
#      74         """
# ---> 75         self.w3c_actions.perform()
#      76
#      77     def reset_actions(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\actions\action_builder.py in perform(self)
#      75                 enc["actions"].append(encoded)
#      76                 device.actions = []
# ---> 77         self.driver.execute(Command.W3C_ACTIONS, enc)
#      78
#      79     def clear_actions(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     398         response = self.command_executor.execute(driver_command, params)
#     399         if response:
# --> 400             self.error_handler.check_response(response)
#     401             response['value'] = self._unwrap_value(
#     402                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     234                 alert_text = value['alert'].get('text')
#     235             raise exception_class(message, screen, stacktrace, alert_text)
# --> 236         raise exception_class(message, screen, stacktrace)
#     237
#     238     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable: [object HTMLInputElement] has no size and location
#   (Session info: chrome=99.0.4844.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00FE9943+2595139]
# 	Ordinal0 [0x00F7C9F1+2148849]
# 	Ordinal0 [0x00E74528+1066280]
# 	Ordinal0 [0x00E76E04+1076740]
# 	Ordinal0 [0x00E76CBE+1076414]
# 	Ordinal0 [0x00E76F50+1077072]
# 	Ordinal0 [0x00EA6ADF+1272543]
# 	Ordinal0 [0x00EA614A+1270090]
# 	Ordinal0 [0x00ED2BEA+1453034]
# 	Ordinal0 [0x00EBB9EC+1358316]
# 	Ordinal0 [0x00ECBAF2+1424114]
# 	Ordinal0 [0x00EBB806+1357830]
# 	Ordinal0 [0x00E96086+1204358]
# 	Ordinal0 [0x00E96F96+1208214]
# 	GetHandleVerifier [0x0118B232+1658114]
# 	GetHandleVerifier [0x0124312C+2411516]
# 	GetHandleVerifier [0x0107F261+560433]
# 	GetHandleVerifier [0x0107E366+556598]
# 	Ordinal0 [0x00F8286B+2173035]
# 	Ordinal0 [0x00F875F8+2192888]
# 	Ordinal0 [0x00F876E5+2193125]
# 	Ordinal0 [0x00F911FC+2232828]
# 	BaseThreadInitThunk [0x75A8FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307A6E+238]

# %%
# from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
# from selenium.webdriver.common.keys import Keys
# import time
# from selenium.webdriver.common.action_chains import ActionChains

# driver = webdriver.Chrome(r"C:\Users\USER\Documents\Scraping_waghera\chromedriver.exe")

# from selenium.webdriver.support.ui import WebDriverWait
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support import expected_conditions as EC

# from selenium.webdriver.support.ui import Select

# a = ActionChains(driver)

# driver.get("https://www.attheraces.com/results")
# driver.implicitly_wait(10)
# driver.maximize_window()

interested_courses = ['ascot','bangor-on-dee','bath','brighton','chepstow','chester','doncaster','fakenham','ffos las','fontwell','hereford','hexham','lingfield','newcastle','newton abbot','plumpton','ripon','sedgefield','southwell','uttoxeter','windsor','wolverhampton','worcester','yarmouth']

# date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
# date_input.click()

# value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
# select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
# driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
# select_month.select_by_visible_text(value1)

# value2 = driver.find_element_by_xpath("//table[@class='pika-table']/tbody/tr/td[7]/button").click()

# a.move_to_element(date_input).perform()
time.sleep(3)
data = []
for day in range(15):
    
    if (day==0):
        driver.find_element_by_xpath('//header[@class="race-nav__header js-race-nav__header"]').click()
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
        
    else:
        race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

        for i,race_course in enumerate(race_courses):
            

            course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text.lower().strip()

            if course_name in interested_courses:

                races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")


                for j,rac in enumerate(races):
                    race = rac.find_element_by_tag_name('a').get_attribute('href')
                    print(race)
                    data.append(race)

#                         sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
#                         if 'Sectional Times' in sectional_times.text:

#                             WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()

#                             total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
#                             for k in range(len(total_rows)):

#                                 horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a")   
#                                 print(horse_name.text)

#                                 all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
#                                 print(len(all_time))
#                                 for s in range(len(all_time)):
#                                     if s<(len(all_time)-3):
#                                         times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
#                                         print(times.text.split('\n')[0])
#                                         if (s == (len(all_time)-4)):
#                                             horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
#                                             slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
#                                             ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
#                                             time.sleep(2)
#                                             minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
#                                             seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
#                                             conv_time = round((minutes*60+seconds),2)
#                                             print(conv_time)

#                                 all_columns = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[@class='card-header']/div/div")
#                                 print(len(all_columns))
#                                 for m in range(len(all_columns)):
#                                     if m<(len(all_columns)-3):
#                                         column = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[1]/div/div[{m+4}]")
#                                         print(column.text)    

#                             race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
#                             details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
#                             racecourse_name = details1[1]
#                             date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
#                             print(racecourse_name)
#                             print(race_time)
#                             print(date)
#                             print('Sectional Times')
#                             print("-------------------------------------------------------------")
#                         print(len(races))
#                         print(course_name)

    driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)
    driver.find_element_by_xpath('//header[@class="race-nav__header js-race-nav__header"]').click()
#     date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
#     a.move_to_element(date_input).perform()

    previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
    previous.click()

    time.sleep(2)


print(data)
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:39: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//header[@class="race-nav__header js-race-nav__header"]').click()
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:109: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:110: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//header[@class="race-nav__header js-race-nav__header"]').click()
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:114: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:46: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:51: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text.lower().strip()
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1371945736.py:55: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
# C:\Users\alikh\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# https://www.attheraces.com/racecard/Hereford/25-March-2022/1300
# https://www.attheraces.com/racecard/Hereford/25-March-2022/1335
# https://www.attheraces.com/racecard/Hereford/25-March-2022/1410
# https://www.attheraces.com/racecard/Hereford/25-March-2022/1445
# https://www.attheraces.com/racecard/Hereford/25-March-2022/1520
# https://www.attheraces.com/racecard/Hereford/25-March-2022/1555
# https://www.attheraces.com/racecard/Hereford/25-March-2022/1630
# https://www.attheraces.com/racecard/Newcastle/25-March-2022/1740
# https://www.attheraces.com/racecard/Newcastle/25-March-2022/1815
# https://www.attheraces.com/racecard/Newcastle/25-March-2022/1845
# https://www.attheraces.com/racecard/Newcastle/25-March-2022/1915
# https://www.attheraces.com/racecard/Newcastle/25-March-2022/1945
# https://www.attheraces.com/racecard/Newcastle/25-March-2022/2015
# https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1355
# https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1430
# https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1505
# https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1540
# https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1615
# https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1650
# https://www.attheraces.com/racecard/Chepstow/24-March-2022/1355
# https://www.attheraces.com/racecard/Chepstow/24-March-2022/1430
# https://www.attheraces.com/racecard/Chepstow/24-March-2022/1501
# https://www.attheraces.com/racecard/Chepstow/24-March-2022/1531
# https://www.attheraces.com/racecard/Chepstow/24-March-2022/1605
# https://www.attheraces.com/racecard/Chepstow/24-March-2022/1635
# https://www.attheraces.com/racecard/Chepstow/24-March-2022/1705
# https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1412
# https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1447
# https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1517
# https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1547
# https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1617
# https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1647
# https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1717
# https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1355
# https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1430
# https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1505
# https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1540
# https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1615
# https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1650
# https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1725
# https://www.attheraces.com/racecard/Plumpton/21-March-2022/1355
# https://www.attheraces.com/racecard/Plumpton/21-March-2022/1430
# https://www.attheraces.com/racecard/Plumpton/21-March-2022/1505
# https://www.attheraces.com/racecard/Plumpton/21-March-2022/1540
# https://www.attheraces.com/racecard/Plumpton/21-March-2022/1615
# https://www.attheraces.com/racecard/Plumpton/21-March-2022/1650
# https://www.attheraces.com/racecard/Southwell/21-March-2022/1300
# https://www.attheraces.com/racecard/Southwell/21-March-2022/1335
# https://www.attheraces.com/racecard/Southwell/21-March-2022/1410
# https://www.attheraces.com/racecard/Southwell/21-March-2022/1445
# https://www.attheraces.com/racecard/Southwell/21-March-2022/1520
# https://www.attheraces.com/racecard/Southwell/21-March-2022/1555
# https://www.attheraces.com/racecard/Southwell/21-March-2022/1630
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1400
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1430
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1505
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1535
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1610
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1645
# https://www.attheraces.com/racecard/Chepstow/20-March-2022/1715
# https://www.attheraces.com/racecard/Fontwell/19-March-2022/1300
# https://www.attheraces.com/racecard/Fontwell/19-March-2022/1335
# https://www.attheraces.com/racecard/Fontwell/19-March-2022/1411
# https://www.attheraces.com/racecard/Fontwell/19-March-2022/1446
# https://www.attheraces.com/racecard/Fontwell/19-March-2022/1521
# https://www.attheraces.com/racecard/Fontwell/19-March-2022/1556
# https://www.attheraces.com/racecard/Fontwell/19-March-2022/1631
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1358
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1433
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1510
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1543
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1618
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1650
# https://www.attheraces.com/racecard/Newcastle/19-March-2022/1725
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1320
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1350
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1425
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1500
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1535
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1610
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1645
# https://www.attheraces.com/racecard/Uttoxeter/19-March-2022/1718
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/1655
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/1730
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/1800
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/1830
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/1900
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/1930
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/2000
# https://www.attheraces.com/racecard/Wolverhampton/19-March-2022/2030
# https://www.attheraces.com/racecard/Doncaster/18-March-2022/1320
# https://www.attheraces.com/racecard/Doncaster/18-March-2022/1400
# https://www.attheraces.com/racecard/Doncaster/18-March-2022/1440
# https://www.attheraces.com/racecard/Doncaster/18-March-2022/1520
# https://www.attheraces.com/racecard/Doncaster/18-March-2022/1600
# https://www.attheraces.com/racecard/Doncaster/18-March-2022/1635
# https://www.attheraces.com/racecard/Doncaster/18-March-2022/1710
# https://www.attheraces.com/racecard/Fakenham/18-March-2022/1310
# https://www.attheraces.com/racecard/Fakenham/18-March-2022/1345
# https://www.attheraces.com/racecard/Fakenham/18-March-2022/1425
# https://www.attheraces.com/racecard/Fakenham/18-March-2022/1505
# https://www.attheraces.com/racecard/Fakenham/18-March-2022/1545
# https://www.attheraces.com/racecard/Fakenham/18-March-2022/1625
# https://www.attheraces.com/racecard/Fakenham/18-March-2022/1700
# https://www.attheraces.com/racecard/Newcastle/18-March-2022/1745
# https://www.attheraces.com/racecard/Newcastle/18-March-2022/1815
# https://www.attheraces.com/racecard/Newcastle/18-March-2022/1845
# https://www.attheraces.com/racecard/Newcastle/18-March-2022/1915
# https://www.attheraces.com/racecard/Newcastle/18-March-2022/1945
# https://www.attheraces.com/racecard/Newcastle/18-March-2022/2015
# https://www.attheraces.com/racecard/Wolverhampton/18-March-2022/1720
# https://www.attheraces.com/racecard/Wolverhampton/18-March-2022/1800
# https://www.attheraces.com/racecard/Wolverhampton/18-March-2022/1830
# https://www.attheraces.com/racecard/Wolverhampton/18-March-2022/1900
# https://www.attheraces.com/racecard/Wolverhampton/18-March-2022/1930
# https://www.attheraces.com/racecard/Wolverhampton/18-March-2022/2000
# https://www.attheraces.com/racecard/Wolverhampton/18-March-2022/2030
# https://www.attheraces.com/racecard/Hexham/17-March-2022/1345
# https://www.attheraces.com/racecard/Hexham/17-March-2022/1425
# https://www.attheraces.com/racecard/Hexham/17-March-2022/1505
# https://www.attheraces.com/racecard/Hexham/17-March-2022/1545
# https://www.attheraces.com/racecard/Hexham/17-March-2022/1625
# https://www.attheraces.com/racecard/Hexham/17-March-2022/1710
# https://www.attheraces.com/racecard/Hexham/17-March-2022/1745
# https://www.attheraces.com/racecard/Southwell/17-March-2022/1620
# https://www.attheraces.com/racecard/Southwell/17-March-2022/1700
# https://www.attheraces.com/racecard/Southwell/17-March-2022/1740
# https://www.attheraces.com/racecard/Southwell/17-March-2022/1815
# https://www.attheraces.com/racecard/Southwell/17-March-2022/1845
# https://www.attheraces.com/racecard/Southwell/17-March-2022/1915
# https://www.attheraces.com/racecard/Southwell/17-March-2022/1945
# https://www.attheraces.com/racecard/Southwell/17-March-2022/2015
# https://www.attheraces.com/racecard/Wolverhampton/17-March-2022/1800
# https://www.attheraces.com/racecard/Wolverhampton/17-March-2022/1830
# https://www.attheraces.com/racecard/Wolverhampton/17-March-2022/1900
# https://www.attheraces.com/racecard/Wolverhampton/17-March-2022/1930
# https://www.attheraces.com/racecard/Wolverhampton/17-March-2022/2000
# https://www.attheraces.com/racecard/Wolverhampton/17-March-2022/2030
# https://www.attheraces.com/racecard/Newcastle/16-March-2022/1714
# https://www.attheraces.com/racecard/Newcastle/16-March-2022/1745
# https://www.attheraces.com/racecard/Newcastle/16-March-2022/1815
# https://www.attheraces.com/racecard/Newcastle/16-March-2022/1845
# https://www.attheraces.com/racecard/Newcastle/16-March-2022/1915
# https://www.attheraces.com/racecard/Newcastle/16-March-2022/1945
# https://www.attheraces.com/racecard/Newcastle/15-March-2022/1745
# https://www.attheraces.com/racecard/Newcastle/15-March-2022/1815
# https://www.attheraces.com/racecard/Newcastle/15-March-2022/1845
# https://www.attheraces.com/racecard/Newcastle/15-March-2022/1915
# https://www.attheraces.com/racecard/Newcastle/15-March-2022/1945
# https://www.attheraces.com/racecard/Newcastle/15-March-2022/2015
# https://www.attheraces.com/racecard/Sedgefield/15-March-2022/1315
# https://www.attheraces.com/racecard/Sedgefield/15-March-2022/1350
# https://www.attheraces.com/racecard/Sedgefield/15-March-2022/1430
# https://www.attheraces.com/racecard/Sedgefield/15-March-2022/1510
# https://www.attheraces.com/racecard/Sedgefield/15-March-2022/1550
# https://www.attheraces.com/racecard/Sedgefield/15-March-2022/1630
# https://www.attheraces.com/racecard/Sedgefield/15-March-2022/1710
# https://www.attheraces.com/racecard/Southwell/15-March-2022/1720
# https://www.attheraces.com/racecard/Southwell/15-March-2022/1755
# https://www.attheraces.com/racecard/Southwell/15-March-2022/1830
# https://www.attheraces.com/racecard/Southwell/15-March-2022/1900
# https://www.attheraces.com/racecard/Southwell/15-March-2022/1930
# https://www.attheraces.com/racecard/Southwell/15-March-2022/2000
# https://www.attheraces.com/racecard/Southwell/15-March-2022/2030
# https://www.attheraces.com/racecard/Plumpton/14-March-2022/1300
# https://www.attheraces.com/racecard/Plumpton/14-March-2022/1335
# https://www.attheraces.com/racecard/Plumpton/14-March-2022/1410
# https://www.attheraces.com/racecard/Plumpton/14-March-2022/1445
# https://www.attheraces.com/racecard/Plumpton/14-March-2022/1520
# https://www.attheraces.com/racecard/Plumpton/14-March-2022/1555
# https://www.attheraces.com/racecard/Wolverhampton/14-March-2022/1700
# https://www.attheraces.com/racecard/Wolverhampton/14-March-2022/1730
# https://www.attheraces.com/racecard/Wolverhampton/14-March-2022/1800
# https://www.attheraces.com/racecard/Wolverhampton/14-March-2022/1830
# https://www.attheraces.com/racecard/Wolverhampton/14-March-2022/1900
# https://www.attheraces.com/racecard/Wolverhampton/14-March-2022/1930
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1402
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1438
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1513
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1548
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1623
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1658
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1402
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1438
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1513
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1548
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1623
# https://www.attheraces.com/racecard/Bangor-On-Dee/13-March-2022/1658
# ['https://www.attheraces.com/racecard/Hereford/25-March-2022/1300', 'https://www.attheraces.com/racecard/Hereford/25-March-2022/1335', 'https://www.attheraces.com/racecard/Hereford/25-March-2022/1410', 'https://www.attheraces.com/racecard/Hereford/25-March-2022/1445', 'https://www.attheraces.com/racecard/Hereford/25-March-2022/1520', 'https://www.attheraces.com/racecard/Hereford/25-March-2022/1555', 'https://www.attheraces.com/racecard/Hereford/25-March-2022/1630', 'https://www.attheraces.com/racecard/Newcastle/25-March-2022/1740', 'https://www.attheraces.com/racecard/Newcastle/25-March-2022/1815', 'https://www.attheraces.com/racecard/Newcastle/25-March-2022/1845', 'https://www.attheraces.com/racecard/Newcastle/25-March-2022/1915', 'https://www.attheraces.com/racecard/Newcastle/25-March-2022/1945', 'https://www.attheraces.com/racecard/Newcastle/25-March-2022/2015', 'https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1355', 'https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1430', 'https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1505', 'https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1540', 'https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1615', 'https://www.attheraces.com/racecard/Newton-Abbot/25-March-2022/1650', 'https://www.attheraces.com/racecard/Chepstow/24-March-2022/1355', 'https://www.attheraces.com/racecard/Chepstow/24-March-2022/1430', 'https://www.attheraces.com/racecard/Chepstow/24-March-2022/1501', 'https://www.attheraces.com/racecard/Chepstow/24-March-2022/1531', 'https://www.attheraces.com/racecard/Chepstow/24-March-2022/1605', 'https://www.attheraces.com/racecard/Chepstow/24-March-2022/1635', 'https://www.attheraces.com/racecard/Chepstow/24-March-2022/1705', 'https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1412', 'https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1447', 'https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1517', 'https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1547', 'https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1617', 'https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1647', 'https://www.attheraces.com/racecard/Sedgefield/24-March-2022/1717', 'https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1355', 'https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1430', 'https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1505', 'https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1540', 'https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1615', 'https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1650', 'https://www.attheraces.com/racecard/Ffos-Las/23-March-2022/1725', 'https://www.attheraces.com/racecard/Plumpton/21-March-2022/1355', 'https://www.attheraces.com/racecard/Plumpton/21-March-2022/1430', 'https://www.attheraces.com/racecard/Plumpton/21-March-2022/1505', 'https://www.attheraces.com/racecard/Plumpton/21-March-2022/1540', 'https://www.attheraces.com/racecard/Plumpton/21-March-2022/1615', 'https://www.attheraces.com/racecard/Plumpton/21-March-2022/1650', 'https://www.attheraces.com/racecard/Southwell/21-March-2022/1300', 'https://www.attheraces.com/racecard/Southwell/21-March-2022/1335', 'https://www.attheraces.com/racecard/Southwell/21-March-2022/1410', 'https://www.attheraces.com/racecard/Southwell/21-March-2022/1445', 'https://www.attheraces.com/racecard/Southwell/21-March-2022/1520', 'https://www.attheraces.com/racecard/Southwell/21-March-2022/1555', 'https://www.attheraces.com/racecard/Southwell/21-March-2022/1630', 'https://www.attheraces.com/racecard/Chepstow/20-March-2022/1400', 'https://www.attheraces.com/racecard/Chepstow/20-March-2022/1430', 'https://www.attheraces.com/racecard/Chepstow/20-March-2022/1505', 'https://www.attheraces.com/racecard/Chepstow/20-March-2022/1535', 'https://www.attheraces.com/racecard/Chepstow/20-March-2022/1610', 'https://www.attheraces.com/racecard/Chepstow/20-March-2022/16 ...

# %%
comp_data = []
ss = {}

# %%
import datefinder,re

# %%
driver.get(data[0])

# %%
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()

# %%
total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\2304659838.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")

# %%
total_rows
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="4eb05529-ab58-4fae-b681-44df90e93638")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="0911818c-0dfa-471c-945e-45002cc3f34e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="dc388c0d-0737-4120-8d7c-776c31df0ea1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="3b91f051-7649-4186-9dad-51d14361bfce")>]

# %%
lin = []
for j in data:
    driver.get(j)
    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
    if 'Sectional Times' in sectional_times.text:
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()
#         sectional_times.click()
        total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
        all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')
        time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text
        all_colu = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"]')
        print(time_name_date)
        for i,j in enumerate(all_times):
            horse = driver.find_element_by_xpath(f'//div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div[3]/div/div/h2/a').text
            print(horse)
            inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
            for k in inner_ele:
                if k.text == '':
                    continue
                print(k.text)
            print('\n')
        print('Sectional Times')
        print('*********************************')
#     lin.append(sectional_times)
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1080376830.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1080376830.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1080376830.py:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1080376830.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1080376830.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_colu = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"]')
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1080376830.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horse = driver.find_element_by_xpath(f'//div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div[3]/div/div/h2/a').text
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\1080376830.py:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
# 13:00 Hereford 25 Mar 2022
#
# 1
# 86.62
# REAR
# 61.22
# REAR
# 57.58
# REAR
# 27.98
# REAR
# 26.66
# 27.59
# FRONT
# 14.54
# FRONT
# 15.58
# FRONT
#
#
# GRANGE ROAD
# 86.02
# FRONT
# 61.13
# FRONT
# 57.73
# FRONT
# 28.21
# FRONT
# 26.80
# FRONT
# 28.45
# 14.44
# 15.98
#
#
# MALAITA
# 86.45
# 61.14
# 57.56
# 28.04
# 27.30
# 30.23
# REAR
# 15.39
# 17.01
#
#
# EL ROJO GRANDE
# 86.21
# 61.01
# FRONT
# 57.71
# FRONT
# 28.28
# 27.65
# REAR
# 29.82
# REAR
# 15.57
# REAR
# 17.89
# REAR
#
#
# Sectional Times
# *********************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 lin = []
#       2 for j in data:
# ----> 3     driver.get(j)
#       4     sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
#       5     if 'Sectional Times' in sectional_times.text:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:436, in WebDriver.get(self, url)
#     432 def get(self, url: str) -> None:
#     433     """
#     434     Loads a web page in the current browser session.
#     435     """
# --> 436     self.execute(Command.GET, {'url': url})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:422, in WebDriver.execute(self, driver_command, params)
#     419         params['sessionId'] = self.session_id
#     421 params = self._wrap_value(params)
# --> 422 response = self.command_executor.execute(driver_command, params)
#     423 if response:
#     424     self.error_handler.check_response(response)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:421, in RemoteConnection.execute(self, command, params)
#     419 data = utils.dump_json(params)
#     420 url = f"{self._url}{path}"
# --> 421 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:443, in RemoteConnection._request(self, method, url, body)
#     440     body = None
#     442 if self.keep_alive:
# --> 443     resp = self._conn.request(method, url, body=body, headers=headers)
#     444     statuscode = resp.status
#     445 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3\lib\site-packages\urllib3\poolmanager.py:375, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     373     response = conn.urlopen(method, url, **kw)
#     374 else:
# --> 375     response = conn.urlopen(method, u.request_uri, **kw)
#     377 redirect_location = redirect and response.get_redirect_location()
#     378 if not redirect_location:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1371, in HTTPConnection.getresponse(self)
#    1369 try:
#    1370     try:
# -> 1371         response.begin()
#    1372     except ConnectionError:
#    1373         self.close()
#
# File ~\anaconda3\lib\http\client.py:319, in HTTPResponse.begin(self)
#     317 # read until we get a non-100 response
#     318 while True:
# --> 319     version, status, reason = self._read_status()
#     320     if status != CONTINUE:
#     321         break
#
# File ~\anaconda3\lib\http\client.py:280, in HTTPResponse._read_status(self)
#     279 def _read_status(self):
# --> 280     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281     if len(line) > _MAXLINE:
#     282         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
for link in data:
    driver.get(link)
    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
    if 'Sectional Times' in sectional_times.text:

        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()
        
        race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
        details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
        matches = datefinder.find_dates(driver.find_element_by_xpath("//h2[@class='h4 flush']").text)
        c = 0
        for match in matches:
            if c==0:
                c+=1
                continue
            date = f'{match.day}/{match.month}/{match.year}'
#         racecourse_name = details1[1]
        ress = re.findall('\d+ [A-Za-z]+ \d+|\d+ [A-Za-z]+ [A-Za-z]+ \d+',driver.find_element_by_xpath("//h2[@class='h4 flush']").text)
        racecourse_name = ''
        for i in ress[0].split(' '):
            if i.isdigit():
                continue
            else:
                racecourse_name += i+' '
#                 print(i)
    #         date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
        print(racecourse_name)
        print(race_time)
        print(date)
        mm = {}
        total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
        for k in range(len(total_rows)):
            
            time.sleep(5)
            horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a").text   
            print(horse_name)

            all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
            print(len(all_time))
            
            inner_list = []
            for s in range(len(all_time)):
                
                if s<(len(all_time)-3):
                    times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
                    print(times.text.split('\n')[0])
                    
                    if (s == (len(all_time)-4)):
                        if (len(all_time)>6):
                            horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                            slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
                            ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                        time.sleep(2)
                      
                        minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
                        if 's' in times.text:
                            seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
                            conv_time = round((minutes*60+seconds),2)
                            print(conv_time)
                        else:
                            conv_time = round((minutes*60),2)
                            print(conv_time)
                     
                    else:
                        inner_list.append(times.text.split('\n')[0])
#                         if (s==0):
            if k == 0:
                mm['date'] = date
                mm['course_name'] = racecourse_name
                mm['race_time']=race_time
            mm[horse_name] = {'Finish':conv_time,'Times':inner_list}      

        print('Sectional Times')
        ss[link] = mm
        
        
        
        print("-------------------------------------------------------------")
    print(len(races))
    print(course_name)
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   matches = datefinder.find_dates(driver.find_element_by_xpath("//h2[@class='h4 flush']").text)
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ress = re.findall('\d+ [A-Za-z]+ \d+|\d+ [A-Za-z]+ [A-Za-z]+ \d+',driver.find_element_by_xpath("//h2[@class='h4 flush']").text)
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:31: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
# Hereford
# 13:00
# 25/3/2022
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a").text
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:45: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
# GRIS MAJEUR
# 12
# 86.62
# 61.22
# 57.58
# 27.98
# 26.66
# 27.59
# 14.54
# 15.58
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:50: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\3566526704.py:51: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
# 317.76
# GRANGE ROAD
# 12
#
# 61.13
# 57.73
# 28.21
# 26.80
# 28.45
# 14.44
# 15.98
# 5m 18.74s
# 318.74
# MALAITA
# 12
#
# 61.14
# 57.56
# 28.04
# 27.30
# 30.23
# 15.39
# 17.01
# 5m 23.13s
# 323.13
# EL ROJO GRANDE
# 12
#
# 61.01
# 57.71
# 28.28
# 27.65
# 29.82
# 15.57
# 17.89
# 5m 24.12s
# 324.12
# Sectional Times
# -------------------------------------------------------------
# 6
# warwick
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
#       1 for link in data:
# ----> 2     driver.get(link)
#       3     sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
#       4     if 'Sectional Times' in sectional_times.text:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:436, in WebDriver.get(self, url)
#     432 def get(self, url: str) -> None:
#     433     """
#     434     Loads a web page in the current browser session.
#     435     """
# --> 436     self.execute(Command.GET, {'url': url})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:422, in WebDriver.execute(self, driver_command, params)
#     419         params['sessionId'] = self.session_id
#     421 params = self._wrap_value(params)
# --> 422 response = self.command_executor.execute(driver_command, params)
#     423 if response:
#     424     self.error_handler.check_response(response)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:421, in RemoteConnection.execute(self, command, params)
#     419 data = utils.dump_json(params)
#     420 url = f"{self._url}{path}"
# --> 421 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:443, in RemoteConnection._request(self, method, url, body)
#     440     body = None
#     442 if self.keep_alive:
# --> 443     resp = self._conn.request(method, url, body=body, headers=headers)
#     444     statuscode = resp.status
#     445 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3\lib\site-packages\urllib3\poolmanager.py:375, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     373     response = conn.urlopen(method, url, **kw)
#     374 else:
# --> 375     response = conn.urlopen(method, u.request_uri, **kw)
#     377 redirect_location = redirect and response.get_redirect_location()
#     378 if not redirect_location:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1371, in HTTPConnection.getresponse(self)
#    1369 try:
#    1370     try:
# -> 1371         response.begin()
#    1372     except ConnectionError:
#    1373         self.close()
#
# File ~\anaconda3\lib\http\client.py:319, in HTTPResponse.begin(self)
#     317 # read until we get a non-100 response
#     318 while True:
# --> 319     version, status, reason = self._read_status()
#     320     if status != CONTINUE:
#     321         break
#
# File ~\anaconda3\lib\http\client.py:280, in HTTPResponse._read_status(self)
#     279 def _read_status(self):
# --> 280     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281     if len(line) > _MAXLINE:
#     282         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
for link in data:
    driver.get(link)
    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
    if 'Sectional Times' in sectional_times.text:

        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()

        total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
        for k in range(len(total_rows)):

            horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a")   
            print(horse_name.text)

            all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
            print(len(all_time))
            for s in range(len(all_time)):
                if s<(len(all_time)-3):
                    times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
                    print(times.text.split('\n')[0])
                    if (s == (len(all_time)-4)):
                        horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                        slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
                        ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                        time.sleep(2)
                        minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
                        seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
                        conv_time = round((minutes*60+seconds),2)
                        print(conv_time)

            all_columns = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[@class='card-header']/div/div")
            print(len(all_columns))
            for m in range(len(all_columns)):
                if m<(len(all_columns)-3):
                    column = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[1]/div/div[{m+4}]")
                    print(column.text)    

        race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
        details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
        racecourse_name = details1[1]
        date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
        print(racecourse_name)
        print(race_time)
        print(date)
        print('Sectional Times')
        print("-------------------------------------------------------------")
    print(len(races))
    print(course_name)
# Out:
# 11
# 111.94
# 64.76
# 31.34
# 29.86
# 29.01
# 13.66
# 15.35
# 4m 55.93s
# 295.93
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SUPER SURVIVOR
# 11
# 111.84
# 65.10
# 31.32
# 29.68
# 29.07
# 13.78
# 15.27
# 4m 56.07s
# 296.07
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# AUTONOMOUS CLOUD
# 11
# 111.48
# 64.78
# 31.36
# 30.11
# 28.95
# 13.96
# 15.44
# 4m 56.07s
# 296.07
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MOURZOUK
# 11
# 111.52
# 65.15
# 31.29
# 29.97
# 30.38
# 14.71
# 17.46
# 5m 0.49s
# 300.49
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Chepstow
# 14:00
# 20 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 124.12
# 62.01
# 67.39
# 32.37
# 32.19
# 30.53
# 15.32
# 16.21
#
# 380.16
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MR KATANGA
# 12
#
# 61.06
# 67.80
# 32.26
# 32.80
# 31.20
# 16.33
# 17.25
# 6m 22.75s
# 382.75
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# JEAN GENIE
# 12
#
# 61.49
# 67.98
# 32.15
# 32.95
# 32.40
# 16.64
# 16.81
# 6m 24.72s
# 384.72
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BRING THE ACTION
# 12
#
# 61.79
# 68.07
# 32.47
# 33.68
# 34.43
# 17.13
# 16.50
# 6m 28.68s
# 388.68
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# STRAIGHT SWAP
# 12
#
# 61.58
# 67.64
# 32.17
# 32.97
# 34.29
# 18.06
# 18.72
# 6m 29.44s
# 389.44
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THOMAS PATRICK
# 12
#
# 62.32
# 68.57
# 32.69
# 33.33
# 34.44
# 17.07
# 17.73
# 6m 30.33s
# 390.33
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# COLONEL KEATING
# 12
#
# 61.65
# 68.48
# 33.04
# 33.60
# 35.70
# 19.17
# 24.53
# 6m 41.33s
# 401.33
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Chepstow
# 14:30
# 20 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 127.33
# 65.80
# 65.76
# 31.70
# 31.38
# 28.30
# 13.64
# 15.05
#
# 378.96
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# PHANTOM GETAWAY
# 12
#
# 66.14
# 65.31
# 31.92
# 31.33
# 28.53
# 13.66
# 15.80
# 6m 19.67s
# 379.67
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RABBLE ROUSER
# 12
#
# 65.88
# 65.74
# 31.66
# 31.70
# 30.10
# 14.52
# 15.75
# 6m 23.06s
# 383.06
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Chepstow
# 15:05
# 20 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 110.38
# 67.05
# 31.18
# 32.15
# 29.35
# 14.95
# 16.31
# 5m 1.38s
# 301.38
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THE WIDDOW MAKER
# 11
# 110.06
# 67.00
# 31.42
# 32.06
# 29.85
# 14.92
# 17.02
# 5m 2.32s
# 302.32
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# YES INDEED
# 11
# 110.65
# 67.16
# 31.05
# 32.55
# 36.40
# 19.22
# 19.65
# 5m 16.67s
# 316.67
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Chepstow
# 15:35
# 20 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 113.84
# 63.99
# 31.22
# 31.19
# 27.72
# 13.03
# 14.45
# 4m 55.44s
# 295.44
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BELLATRIXSA
# 11
# 113.05
# 64.13
# 31.19
# 31.54
# 28.09
# 13.10
# 15.24
# 4m 56.33s
# 296.33
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# WHITEHOTCHILLIFILI
# 11
# 113.55
# 63.73
# 31.19
# 31.46
# 27.78
# 13.40
# 16.58
# 4m 57.70s
# 297.7
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SWINCOMBE FLEAT
# 11
# 113.11
# 64.15
# 31.17
# 31.43
# 28.57
# 14.12
# 17.28
# 4m 59.84s
# 299.84
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# VOLKOVKA
# 11
# 113.68
# 64.06
# 31.31
# 31.42
# 29.66
# 14.90
# 21.89
# 5m 6.93s
# 306.93
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Chepstow
# 16:10
# 20 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 113.73
# 66.76
# 31.64
# 31.85
# 31.51
# 16.06
# 16.01
# 5m 7.54s
# 307.54
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# OXWICH BAY
# 11
# 114.36
# 66.58
# 31.69
# 31.92
# 31.26
# 15.88
# 15.99
# 5m 7.68s
# 307.68
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THE BOAT
# 11
# 114.46
# 66.75
# 31.42
# 32.28
# 31.53
# 15.82
# 16.37
# 5m 8.61s
# 308.61
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BALLYCORR
# 11
# 113.83
# 66.62
# 31.73
# 32.01
# 32.88
# 17.07
# 16.87
# 5m 10.99s
# 310.99
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GAELIC THUNDER
# 11
# 114.16
# 66.72
# 31.82
# 32.99
# 35.85
# 19.08
# 18.77
# 5m 19.37s
# 319.37
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Chepstow
# 16:45
# 20 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 61.62
# 59.42
# 29.72
# 31.06
# 27.79
# 13.64
# 15.04
# 3m 58.29s
# 238.29
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# HERO
# 11
# 62.75
# 59.97
# 29.28
# 30.20
# 27.99
# 14.02
# 14.83
# 3m 59.06s
# 239.06
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GALUDON
# 11
# 62.61
# 59.97
# 29.21
# 30.67
# 28.94
# 13.97
# 14.74
# 4m 0.10s
# 240.1
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# JACK SPRAT
# 11
# 63.11
# 59.58
# 29.25
# 30.49
# 28.47
# 14.16
# 16.13
# 4m 1.18s
# 241.18
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BRESILIANT
# 11
# 62.86
# 59.89
# 29.34
# 30.60
# 29.38
# 14.49
# 15.20
# 4m 1.77s
# 241.77
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# LASTORDERSPLEASE
# 11
# 61.75
# 59.34
# 30.05
# 31.64
# 32.06
# 16.03
# 17.97
# 4m 8.83s
# 248.83
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# ROBINSVILLE
# 11
# 62.45
# 60.16
# 29.24
# 32.29
# 32.70
# 15.64
# 16.84
# 4m 9.33s
# 249.33
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# FOREST ECHO
# 11
# 62.71
# 60.54
# 29.92
# 32.83
# 34.29
# 16.53
# 17.89
# 4m 14.72s
# 254.72
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Chepstow
# 17:15
# 20 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 114.20
# 62.06
# 30.65
# 27.22
# 28.07
# 14.31
# 14.77
# 4m 51.29s
# 291.29
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# WARRANTY
# 11
# 113.67
# 61.87
# 30.40
# 27.10
# 28.49
# 14.57
# 15.31
# 4m 51.42s
# 291.42
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# WHISTLEINTHEDARK
# 11
# 114.51
# 61.94
# 30.84
# 27.18
# 29.10
# 17.23
# 16.81
# 4m 57.61s
# 297.61
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Fontwell
# 13:00
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 86.37
# 59.83
# 30.23
# 27.45
# 28.12
# 14.41
# 14.79
# 4m 21.20s
# 261.2
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# DUSKY DAYS
# 11
# 86.80
# 59.93
# 29.99
# 27.86
# 28.95
# 16.81
# 17.45
# 4m 27.77s
# 267.77
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# URANUS DES BORDES
# 11
# 86.93
# 59.98
# 29.69
# 27.79
# 29.12
# 16.95
# 18.23
# 4m 28.69s
# 268.69
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SALLYANN
# 11
# 87.27
# 59.87
# 30.12
# 28.13
# 31.28
# 17.52
# 16.80
# 4m 30.99s
# 270.99
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SAVE FACE
# 11
# 87.56
# 59.66
# 29.56
# 27.90
# 30.84
# 18.70
# 17.03
# 4m 31.25s
# 271.25
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GIRANDOLE
# 11
# 87.00
# 60.07
# 29.87
# 28.59
# 32.83
# 17.13
# 17.59
# 4m 33.09s
# 273.09
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Fontwell
# 13:35
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 90.54
# 64.98
# 64.34
# 30.75
# 29.40
# 30.52
# 16.54
# 18.76
#
# 345.84
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SILENT ASSISTANT
# 12
#
# 64.81
# 64.56
# 30.71
# 29.32
# 31.08
# 17.23
# 22.56
# 5m 50.82s
# 350.82
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Fontwell
# 14:11
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 90.99
# 61.15
# 64.55
# 29.96
# 29.07
# 30.13
# 15.98
# 17.14
#
# 338.97
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BLACK GERRY
# 12
#
# 61.35
# 64.48
# 29.70
# 28.86
# 30.38
# 17.93
# 18.69
# 5m 42.81s
# 342.81
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# REIGN SUEPREME
# 12
#
# 61.09
# 64.67
# 30.07
# 29.82
# 31.93
# 18.08
# 18.11
# 5m 45.04s
# 345.04
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Fontwell
# 14:46
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 108.74
# 61.18
# 29.22
# 28.07
# 28.75
# 15.87
# 16.60
# 4m 48.45s
# 288.45
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# FRED BEAR
# 11
# 108.61
# 61.31
# 29.32
# 28.15
# 29.62
# 16.25
# 17.03
# 4m 50.31s
# 290.31
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# WEARDIDITALLGORONG
# 11
# 109.73
# 61.17
# 29.82
# 28.27
# 28.62
# 15.48
# 17.48
# 4m 50.57s
# 290.57
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THE HEIGHT OF FAME
# 11
# 108.81
# 61.20
# 29.84
# 28.16
# 29.80
# 15.87
# 17.31
# 4m 51.01s
# 291.01
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# ONE LAST GLANCE
# 11
# 109.22
# 61.22
# 29.45
# 27.83
# 30.41
# 17.77
# 18.83
# 4m 54.72s
# 294.72
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SHUTTHEGATE
# 11
# 109.58
# 61.34
# 29.82
# 28.18
# 32.58
# 17.15
# 16.94
# 4m 55.58s
# 295.58
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# COBBS CORNER
# 11
# 108.86
# 61.35
# 29.91
# 27.95
# 30.15
# 17.89
# 19.63
# 4m 55.74s
# 295.74
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CATCH ME NOT
# 11
# 108.98
# 61.44
# 29.95
# 28.76
# 32.84
# 17.53
# 18.92
# 4m 58.40s
# 298.4
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MY TICKETYBOO
# 11
# 110.36
# 61.64
# 32.30
# 32.00
# 31.62
# 18.09
# 17.09
# 5m 3.10s
# 303.1
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Fontwell
# 15:21
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 88.26
# 65.47
# 30.01
# 29.30
# 31.22
# 16.66
# 17.82
# 4m 38.75s
# 278.75
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# EN COEUR
# 11
# 89.13
# 65.10
# 30.06
# 29.51
# 30.75
# 16.68
# 17.82
# 4m 39.06s
# 279.06
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# LINCOLN LYN
# 11
# 88.90
# 65.23
# 30.57
# 29.32
# 31.85
# 17.03
# 17.68
# 4m 40.57s
# 280.57
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# LE COEUR NET
# 11
# 88.91
# 65.60
# 31.22
# 28.85
# 31.05
# 17.44
# 20.62
# 4m 43.68s
# 283.68
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# HAPPY LARRY
# 11
# 89.31
# 66.69
# 30.76
# 32.16
# 34.20
# 19.10
# 20.99
# 4m 53.21s
# 293.21
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Fontwell
# 15:56
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 13
# 90.80
# 63.59
# 63.09
# 62.93
# 31.41
# 27.35
# 29.57
# 15.58
# 16.61
#
# 400.93
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# AGE OF WISDOM
# 13
#
# 64.10
# 62.88
# 63.17
# 31.53
# 28.08
# 29.61
# 15.90
# 16.31
# 6m 41.17s
# 401.17
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RADDON TOP
# 13
#
# 64.06
# 62.93
# 63.15
# 31.17
# 28.05
# 30.24
# 15.81
# 15.94
# 6m 41.46s
# 401.46
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THE TIN MINER
# 13
#
# 64.38
# 62.76
# 63.60
# 31.49
# 28.19
# 29.70
# 17.19
# 17.33
# 6m 43.27s
# 403.27
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THE REAL JET
# 13
#
# 63.77
# 62.72
# 63.27
# 31.36
# 28.44
# 31.35
# 17.27
# 17.63
# 6m 46.22s
# 406.22
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# ELLEON
# 13
#
# 64.30
# 63.00
# 63.25
# 31.33
# 28.52
# 31.51
# 17.87
# 17.71
# 6m 46.43s
# 406.43
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# ITSABOUTIME
# 13
#
# 63.87
# 62.45
# 63.73
# 31.73
# 28.76
# 30.23
# 18.12
# 23.50
# 6m 53.21s
# 413.21
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# REALLYRADICAL
# 13
#
# 64.09
# 62.80
# 63.17
# 31.86
# 29.95
# 30.40
# 19.54
# 27.22
# 6m 58.79s
# 418.79
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Fontwell
# 16:31
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 69.08
# 59.50
# 30.48
# 29.28
# 27.12
# 14.20
# 14.88
# 4m 4.55s
# 244.55
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# ROYLE STEEL
# 11
# 69.33
# 59.70
# 30.45
# 29.06
# 27.19
# 14.62
# 15.56
# 4m 5.92s
# 245.92
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BALKALIN
# 11
# 68.86
# 59.62
# 30.06
# 29.00
# 28.14
# 15.03
# 15.85
# 4m 6.56s
# 246.56
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# PEPITE FLEURIE
# 11
# 68.60
# 59.38
# 30.34
# 29.27
# 30.59
# 17.63
# 17.86
# 4m 13.67s
# 253.67
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 13:58
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 66.10
# 65.00
# 59.32
# 30.38
# 30.92
# 28.92
# 15.40
# 16.04
#
# 312.09
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# DAWN RAIDER
# 12
#
# 65.01
# 59.49
# 30.17
# 30.98
# 29.62
# 15.28
# 15.48
# 5m 12.34s
# 312.34
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CRACKING FIND
# 12
#
# 65.30
# 59.49
# 30.42
# 30.89
# 29.55
# 15.55
# 16.19
# 5m 12.92s
# 312.92
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SIX ONE NINE
# 12
#
# 65.34
# 59.44
# 30.54
# 30.94
# 29.94
# 15.60
# 17.19
# 5m 14.21s
# 314.21
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BROOMFIELDS KAN
# 12
#
# 64.62
# 59.56
# 30.39
# 30.93
# 29.46
# 16.80
# 17.56
# 5m 15.28s
# 315.28
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SPIDER'S BITE
# 12
#
# 64.79
# 59.45
# 30.65
# 31.11
# 31.48
# 16.07
# 17.02
# 5m 16.80s
# 316.8
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# LASTIN' MEMORIES
# 12
#
# 64.49
# 59.69
# 30.48
# 31.09
# 32.17
# 16.28
# 19.21
# 5m 20.11s
# 320.11
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SHAWS BRIDGE
# 12
#
# 64.85
# 59.73
# 29.90
# 31.26
# 32.52
# 18.24
# 21.32
# 5m 24.40s
# 324.4
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 14:33
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 63.98
# 57.65
# 28.89
# 28.39
# 27.40
# 14.70
# 14.71
# 3m 55.73s
# 235.73
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SAINT ARVANS
# 11
# 63.96
# 57.80
# 28.89
# 28.42
# 27.65
# 14.61
# 14.96
# 3m 56.31s
# 236.31
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THEATRE LEGEND
# 11
# 63.46
# 57.80
# 28.76
# 28.59
# 27.65
# 15.14
# 16.76
# 3m 58.16s
# 238.16
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MINELLA PLUS
# 11
# 63.72
# 57.78
# 28.91
# 28.46
# 28.54
# 16.73
# 17.99
# 4m 2.11s
# 242.11
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 15:10
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 95.98
# 61.07
# 58.48
# 28.88
# 28.59
# 27.47
# 14.26
# 14.81
#
# 329.54
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# JETOILE
# 12
#
# 60.97
# 58.17
# 28.96
# 28.35
# 27.58
# 14.72
# 15.92
# 5m 31.01s
# 331.01
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KAYF HERNANDO
# 12
#
# 61.20
# 58.34
# 29.08
# 28.48
# 28.14
# 15.34
# 16.16
# 5m 32.51s
# 332.51
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RAFFERTY'S RETURN
# 12
#
# 61.06
# 58.46
# 29.09
# 28.49
# 28.03
# 16.52
# 17.56
# 5m 34.80s
# 334.8
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 15:43
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 119.14
# 64.36
# 61.13
# 30.87
# 30.91
# 29.93
# 15.08
# 16.39
#
# 367.81
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RAPID RAIDER
# 12
#
# 64.51
# 61.28
# 30.71
# 30.85
# 29.76
# 15.81
# 16.17
# 6m 7.87s
# 367.87
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CHASE THE WIND
# 12
#
# 64.54
# 61.29
# 30.90
# 30.81
# 30.36
# 15.57
# 16.16
# 6m 7.94s
# 367.94
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MORNINGSIDE
# 12
#
# 64.33
# 61.23
# 30.84
# 30.88
# 30.28
# 15.76
# 16.04
# 6m 8.73s
# 368.73
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GUN MERCHANT
# 12
#
# 64.58
# 61.39
# 30.89
# 30.75
# 31.21
# 15.75
# 16.97
# 6m 9.75s
# 369.75
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SHANBALLY ROSE
# 12
#
# 64.56
# 61.21
# 30.99
# 31.07
# 32.20
# 16.71
# 19.29
# 6m 14.58s
# 374.58
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 16:18
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 66.31
# 60.79
# 58.96
# 30.45
# 30.45
# 27.67
# 13.88
# 13.58
#
# 302.07
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KINONDO KWETU
# 12
#
# 61.16
# 58.89
# 30.53
# 30.54
# 27.74
# 13.90
# 14.05
# 5m 2.59s
# 302.59
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KAJAKI
# 12
#
# 61.09
# 59.04
# 30.49
# 30.46
# 27.89
# 13.78
# 14.21
# 5m 2.65s
# 302.65
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THEOCRAT
# 12
#
# 60.86
# 58.85
# 30.53
# 30.19
# 27.93
# 13.88
# 13.97
# 5m 2.77s
# 302.77
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# IDILICO
# 12
#
# 60.89
# 59.07
# 30.46
# 30.46
# 27.86
# 14.59
# 14.88
# 5m 4.35s
# 304.35
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# DUTY CALLS
# 12
#
# 60.84
# 59.00
# 30.34
# 30.59
# 28.00
# 14.35
# 16.64
# 5m 5.61s
# 305.61
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BEACH BREAK
# 12
#
# 61.11
# 59.13
# 30.42
# 30.56
# 27.91
# 14.60
# 16.58
# 5m 5.64s
# 305.64
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CURRAMORE
# 12
#
# 61.66
# 58.22
# 30.41
# 30.18
# 28.28
# 15.58
# 14.99
# 5m 6.02s
# 306.02
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BAK ROCKY
# 12
#
# 61.10
# 59.19
# 30.43
# 30.62
# 28.87
# 15.59
# 16.19
# 5m 7.24s
# 307.24
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 16:50
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 63.03
# 60.66
# 28.79
# 28.41
# 25.87
# 13.03
# 13.75
# 3m 53.54s
# 233.54
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KNOCKANORE
# 11
# 64.51
# 59.83
# 28.72
# 28.07
# 25.73
# 12.90
# 13.79
# 3m 53.55s
# 233.55
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# NINETOFIVE
# 11
# 63.65
# 60.20
# 28.83
# 28.20
# 25.94
# 13.49
# 14.46
# 3m 54.77s
# 234.77
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# HIDALGO DE L'ISLE
# 11
# 64.51
# 59.61
# 28.93
# 28.14
# 25.70
# 13.34
# 14.60
# 3m 54.84s
# 234.84
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CHASE A FORTUNE
# 11
# 65.48
# 59.66
# 28.81
# 27.67
# 26.31
# 13.89
# 14.53
# 3m 56.34s
# 236.34
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BLAME THE FARRIER
# 11
# 65.27
# 59.49
# 28.91
# 27.67
# 26.18
# 14.02
# 15.84
# 3m 57.37s
# 237.37
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BEING TED
# 11
# 65.16
# 59.50
# 28.70
# 28.14
# 26.37
# 14.39
# 15.89
# 3m 58.16s
# 238.16
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BRAY DALE
# 11
# 64.28
# 59.91
# 28.87
# 28.19
# 27.05
# 14.49
# 15.38
# 3m 58.16s
# 238.16
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# WADMAL
# 11
# 64.36
# 59.76
# 28.93
# 28.18
# 29.06
# 16.83
# 19.00
# 4m 6.11s
# 246.11
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Newcastle
# 17:25
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 122.81
# 62.74
# 30.52
# 28.21
# 27.78
# 14.55
# 15.90
# 5m 2.50s
# 302.5
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# DEL LA MAR ROCKET
# 11
# 121.82
# 63.11
# 30.62
# 28.19
# 28.39
# 15.09
# 16.46
# 5m 3.67s
# 303.67
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# NOTHIN TO ASK
# 11
# 122.24
# 62.98
# 30.55
# 28.48
# 28.50
# 15.10
# 16.38
# 5m 4.23s
# 304.23
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# COUSU MAIN
# 11
# 122.71
# 62.98
# 30.34
# 28.43
# 30.81
# 17.34
# 18.21
# 5m 10.82s
# 310.82
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CAPTAIN GRINNAWAY
# 11
# 121.78
# 63.05
# 30.44
# 28.88
# 32.41
# 16.64
# 19.36
# 5m 12.58s
# 312.58
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 13:20
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 111.03
# 59.50
# 59.57
# 29.96
# 29.28
# 28.40
# 14.26
# 15.31
#
# 347.3
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# PULLING STUMPS
# 12
#
# 60.08
# 59.74
# 30.04
# 29.25
# 28.81
# 14.79
# 16.13
# 5m 48.88s
# 348.88
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# WELSH SAINT
# 12
#
# 59.95
# 59.45
# 30.36
# 29.44
# 31.14
# 15.87
# 16.73
# 5m 52.84s
# 352.84
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# ILLEGAL MODEL
# 12
#
# 60.26
# 59.67
# 30.79
# 30.41
# 32.52
# 16.44
# 17.24
# 5m 56.96s
# 356.96
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SILVA ECLIPSE
# 12
#
# 59.90
# 60.89
# 30.67
# 30.47
# 31.52
# 15.54
# 17.23
# 5m 57.36s
# 357.36
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# KATESON
# 12
#
# 60.55
# 60.77
# 31.72
# 29.75
# 32.75
# 16.03
# 16.83
# 5m 59.39s
# 359.39
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SIDI ISMAEL
# 12
#
# 59.66
# 60.18
# 31.65
# 30.74
# 33.50
# 17.89
# 20.98
# 6m 5.03s
# 365.03
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 13:50
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 13
# 66.22
# 67.97
# 63.34
# 63.19
# 31.34
# 29.56
# 29.39
# 14.02
# 15.43
#
# 380.45
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GUSTAVIAN
# 13
#
# 67.61
# 63.16
# 63.05
# 31.86
# 29.45
# 29.09
# 14.64
# 15.26
# 6m 21.20s
# 381.2
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MIDNIGHT RIVER
# 13
#
# 67.61
# 63.43
# 63.18
# 31.32
# 29.65
# 29.34
# 14.29
# 15.77
# 6m 21.38s
# 381.38
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# YOUNG BULL
# 13
#
# 67.61
# 63.48
# 63.24
# 31.27
# 29.46
# 29.63
# 14.74
# 16.31
# 6m 22.01s
# 382.01
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# FUJI FLIGHT
# 13
#
# 67.57
# 63.12
# 63.37
# 31.35
# 29.55
# 29.77
# 14.93
# 15.31
# 6m 22.13s
# 382.13
# 13
#
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 14:25
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 118.56
# 59.39
# 30.17
# 27.83
# 28.06
# 13.90
# 14.35
# 4m 52.25s
# 292.25
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BOOTHILL
# 11
# 119.08
# 59.92
# 29.60
# 27.70
# 27.86
# 13.67
# 14.63
# 4m 52.45s
# 292.45
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# PANIC ATTACK
# 11
# 118.71
# 59.63
# 30.00
# 27.80
# 28.83
# 15.01
# 16.35
# 4m 56.32s
# 296.32
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# JEPECK
# 11
# 118.30
# 60.21
# 29.99
# 27.90
# 29.75
# 15.82
# 16.68
# 4m 58.64s
# 298.64
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# JETAWAY JOEY
# 11
# 118.86
# 60.03
# 29.71
# 27.68
# 30.37
# 15.82
# 17.21
# 4m 59.68s
# 299.68
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# CH'TIBELLO
# 11
# 119.28
# 59.53
# 29.92
# 28.92
# 30.72
# 16.24
# 17.38
# 5m 2.00s
# 302.0
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# TEESCOMPONENTSYESS
# 11
# 118.53
# 59.86
# 30.01
# 28.83
# 30.97
# 16.34
# 18.01
# 5m 2.55s
# 302.55
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RED RISK
# 11
# 118.79
# 59.68
# 30.28
# 29.37
# 32.07
# 16.39
# 17.88
# 5m 4.47s
# 304.47
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# HAAFAPIECE
# 11
# 118.92
# 59.93
# 30.54
# 29.98
# 32.16
# 16.31
# 17.72
# 5m 5.57s
# 305.57
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 15:00
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 14
# 161.06
# 66.59
# 66.73
# 63.26
# 64.19
# 31.87
# 30.79
# 30.73
# 15.13
# 15.70
#
# 546.06
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# YOUNG DEV
# 14
#
# 65.93
# 67.23
# 63.05
# 64.27
# 32.17
# 30.51
# 30.50
# 15.52
# 17.03
# 9m 8.56s
# 548.56
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# TIME TO GET UP
# 14
#
# 66.48
# 67.28
# 63.18
# 64.43
# 31.94
# 30.62
# 31.55
# 15.69
# 17.24
# 9m 9.06s
# 549.06
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# EL PASO WOOD
# 14
#
# 66.30
# 67.31
# 62.83
# 63.91
# 31.81
# 30.77
# 31.13
# 16.62
# 19.07
# 9m 11.00s
# 551.0
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MOMELLA
# 14
#
# 66.39
# 67.52
# 63.41
# 64.30
# 32.22
# 31.20
# 32.72
# 16.19
# 16.62
# 9m 11.24s
# 551.24
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# TRUCKERS LODGE
# 14
#
# 66.57
# 67.16
# 63.02
# 64.29
# 31.97
# 30.73
# 32.08
# 17.94
# 18.12
# 9m 12.33s
# 552.33
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# PADLEYOUROWNCANOE
# 14
#
# 66.53
# 67.54
# 63.06
# 64.26
# 32.34
# 31.08
# 33.03
# 18.12
# 20.68
# 9m 16.86s
# 556.86
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# DE YOUNG WARRIOR
# 14
#
# 66.45
# 67.31
# 63.27
# 64.20
# 32.23
# 31.41
# 34.49
# 17.44
# 19.13
# 9m 16.89s
# 556.89
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GWENCILY BERBAS
# 14
#
# 66.15
# 67.38
# 62.83
# 64.11
# 31.94
# 31.20
# 33.69
# 18.08
# 21.00
# 9m 17.57s
# 557.57
# 14
#
# 24f-20f
# 20f-16f
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 15:35
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 58.44
# 62.75
# 31.08
# 28.92
# 28.26
# 14.28
# 16.36
# 4m 0.10s
# 240.1
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BORN TO PLEASE
# 11
# 58.79
# 62.95
# 31.25
# 28.73
# 29.16
# 15.19
# 16.30
# 4m 2.40s
# 242.4
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# RACHEL LOUISE
# 11
# 58.59
# 62.61
# 31.27
# 28.95
# 29.54
# 15.39
# 16.11
# 4m 2.47s
# 242.47
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SIMPLY RED
# 11
# 58.14
# 62.80
# 31.12
# 28.93
# 28.70
# 16.28
# 16.55
# 4m 2.53s
# 242.53
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# BRANSON MISSOURI
# 11
# 58.34
# 62.80
# 31.29
# 29.03
# 31.05
# 16.16
# 17.55
# 4m 6.23s
# 246.23
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 16:10
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 12
# 65.73
# 62.12
# 63.03
# 32.19
# 30.25
# 30.15
# 15.90
# 18.81
#
# 318.2
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# TOWN PARKS
# 12
#
# 62.31
# 63.44
# 32.11
# 29.97
# 31.17
# 17.00
# 19.08
# 5m 20.15s
# 320.15
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# NEIL THE LEGEND
# 12
#
# 62.36
# 63.45
# 32.09
# 30.21
# 32.54
# 17.40
# 20.13
# 5m 22.81s
# 322.81
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# THE DUBAI WAY
# 12
#
# 62.25
# 63.33
# 32.22
# 30.53
# 33.33
# 17.64
# 18.68
# 5m 23.26s
# 323.26
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# HONORARY COLONEL
# 12
#
# 62.08
# 63.11
# 31.94
# 30.08
# 33.74
# 18.66
# 24.65
# 5m 29.95s
# 329.95
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 16:45
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 11
# 57.53
# 60.21
# 29.57
# 28.31
# 26.81
# 13.46
# 14.31
# 3m 50.20s
# 230.2
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# SAINT BIBIANA
# 11
# 57.23
# 60.23
# 29.65
# 28.45
# 27.04
# 14.12
# 14.60
# 3m 51.30s
# 231.3
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# GAELIC PARK
# 11
# 57.45
# 60.33
# 29.57
# 28.24
# 26.68
# 14.01
# 15.11
# 3m 51.39s
# 231.39
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# MASTER CHEWY
# 11
# 57.30
# 60.13
# 29.58
# 28.53
# 26.51
# 14.22
# 15.56
# 3m 51.82s
# 231.82
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# LUKE THE DRIFTER
# 11
# 57.72
# 60.28
# 29.39
# 28.53
# 27.92
# 15.09
# 15.92
# 3m 54.83s
# 234.83
# 11
# Start-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish
# Uttoxeter
# 17:18
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 13
# 20.09
# 12.34
# 12.49
# 12.19
# 12.21
# 12.46
# 12.50
# 12.18
# 12.52
#
# 119.0
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# BOASTY
# 13
#
# 12.09
# 12.54
# 12.27
# 12.23
# 12.58
# 12.40
# 12.03
# 12.48
# 1m 59.06s
# 119.06
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# PILOT WINGS
# 13
#
# 11.94
# 12.44
# 12.29
# 12.19
# 12.51
# 12.35
# 12.13
# 12.59
# 1m 59.26s
# 119.26
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# PARIKARMA
# 13
#
# 12.06
# 12.42
# 12.19
# 12.23
# 12.49
# 12.55
# 12.42
# 12.38
# 2m 0.19s
# 120.19
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# CITY ESCAPE
# 13
#
# 11.87
# 12.32
# 12.22
# 12.20
# 12.49
# 13.32
# 12.15
# 12.36
# 2m 0.30s
# 120.3
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# RIVAS ROB ROY
# 13
#
# 12.05
# 12.51
# 12.26
# 12.23
# 12.59
# 12.79
# 12.83
# 13.23
# 2m 0.53s
# 120.53
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# COPAKE
# 13
#
# 12.14
# 12.44
# 12.19
# 12.26
# 12.54
# 12.79
# 12.82
# 13.01
# 2m 0.69s
# 120.69
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# JACK BEAN
# 13
#
# 12.10
# 12.44
# 12.20
# 12.26
# 12.63
# 13.28
# 13.08
# 13.45
# 2m 2.09s
# 122.09
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# DESERT CAT
# 13
#
# 12.14
# 12.34
# 12.23
# 12.32
# 12.44
# 12.63
# 13.07
# 14.10
# 2m 2.26s
# 122.26
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# NEW LOOK
# 13
#
# 12.07
# 12.40
# 12.19
# 12.22
# 12.75
# 13.12
# 13.17
# 14.37
# 2m 2.97s
# 122.97
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# Wolverhampton
# 16:55
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 13
# 20.90
# 12.45
# 13.09
# 12.99
# 12.73
# 12.77
# 12.38
# 12.12
# 12.43
#
# 121.86
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# NINE ELMS
# 13
#
# 12.51
# 13.17
# 13.01
# 12.66
# 12.72
# 12.64
# 12.13
# 12.64
# 2m 2.04s
# 122.04
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# UTHER PENDRAGON
# 13
#
# 12.50
# 13.08
# 13.07
# 12.57
# 12.91
# 12.61
# 12.50
# 12.56
# 2m 2.16s
# 122.16
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# QUOTELINE DIRECT
# 13
#
# 12.61
# 13.14
# 13.21
# 12.66
# 12.75
# 12.31
# 11.99
# 12.45
# 2m 2.22s
# 122.22
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# AMALFI SALSA
# 13
#
# 12.57
# 13.29
# 13.01
# 12.64
# 12.68
# 12.46
# 12.48
# 12.62
# 2m 2.24s
# 122.24
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# TENTH CENTURY
# 13
#
# 12.61
# 13.14
# 13.02
# 12.64
# 12.82
# 12.53
# 12.62
# 13.08
# 2m 2.82s
# 122.82
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# AIR OF YORK
# 13
#
# 12.80
# 13.11
# 13.16
# 12.66
# 12.86
# 12.60
# 12.38
# 12.69
# 2m 2.89s
# 122.89
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# DYLAN'S RUBY
# 13
#
# 12.69
# 13.22
# 13.17
# 12.60
# 12.73
# 12.53
# 12.23
# 12.88
# 2m 2.95s
# 122.95
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# CASARUAN
# 13
#
# 12.76
# 13.30
# 12.99
# 12.58
# 12.69
# 12.70
# 12.56
# 13.09
# 2m 3.26s
# 123.26
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# ROCKY SEA
# 13
#
# 12.48
# 13.07
# 13.12
# 12.68
# 12.80
# 12.52
# 12.63
# 13.72
# 2m 4.16s
# 124.16
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# BEATRIX ENCHANTE
# 13
#
# 12.63
# 12.96
# 12.98
# 12.56
# 12.84
# 12.98
# 13.62
# 14.87
# 2m 6.17s
# 126.17
# 13
#
# 8f-7f
# 7f-6f
# 6f-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# Wolverhampton
# 17:30
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 10
# 14.90
# 11.30
# 11.48
# 11.72
# 12.00
# 12.84
# 1m 14.25s
# 74.25
# 10
# Start-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# WESTERN MELODY
# 10
# 15.08
# 11.28
# 11.62
# 11.76
# 12.04
# 12.52
# 1m 14.31s
# 74.31
# 10
# Start-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# GENERAL SAGO
# 10
# 14.77
# 11.26
# 11.48
# 11.73
# 12.18
# 13.12
# 1m 14.55s
# 74.55
# 10
# Start-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# LEXINGTON BULLET
# 10
# 14.99
# 11.31
# 11.60
# 11.85
# 12.21
# 13.55
# 1m 15.51s
# 75.51
# 10
# Start-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# LEVENDI
# 10
# 15.20
# 11.28
# 11.58
# 11.94
# 12.58
# 16.33
# 1m 18.91s
# 78.91
# 10
# Start-5f
# 5f-4f
# 4f-3f
# 3f-2f
# 2f-1f
# 1f-Finish
# Finish
# Wolverhampton
# 18:00
# 19 Mar 2022
# Sectional Times
# -------------------------------------------------------------
# 7
# wolverhampton
#
# 9
# 15.06
# 11.10
# 11.12
# 11.10
# 11.61
# 1m
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-9-3c4288a333d2> in <module>
#      19                     print(times.text.split('\n')[0])
#      20                     if (s == (len(all_time)-4)):
# ---> 21                         horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
#      22                         slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
#      23                         ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     482         """
#     483         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 484         return self.find_element(by=By.XPATH, value=xpath)
#     485
#     486     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1151             value = '[name="%s"]' % value
#    1152
# -> 1153         return self.execute(Command.FIND_ELEMENT, {
#    1154             'using': by,
#    1155             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     398         response = self.command_executor.execute(driver_command, params)
#     399         if response:
# --> 400             self.error_handler.check_response(response)
#     401             response['value'] = self._unwrap_value(
#     402                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     234                 alert_text = value['alert'].get('text')
#     235             raise exception_class(message, screen, stacktrace, alert_text)
# --> 236         raise exception_class(message, screen, stacktrace)
#     237
#     238     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class="js-scrollbar__track scrollbar__track"]"}
#   (Session info: chrome=99.0.4844.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00FE9943+2595139]
# 	Ordinal0 [0x00F7C9F1+2148849]
# 	Ordinal0 [0x00E74528+1066280]
# 	Ordinal0 [0x00EA0FD4+1249236]
# 	Ordinal0 [0x00EA11CB+1249739]
# 	Ordinal0 [0x00ECD812+1431570]
# 	Ordinal0 [0x00EBBA34+1358388]
# 	Ordinal0 [0x00ECBAF2+1424114]
# 	Ordinal0 [0x00EBB806+1357830]
# 	Ordinal0 [0x00E96086+1204358]
# 	Ordinal0 [0x00E96F96+1208214]
# 	GetHandleVerifier [0x0118B232+1658114]
# 	GetHandleVerifier [0x0124312C+2411516]
# 	GetHandleVerifier [0x0107F261+560433]
# 	GetHandleVerifier [0x0107E366+556598]
# 	Ordinal0 [0x00F8286B+2173035]
# 	Ordinal0 [0x00F875F8+2192888]
# 	Ordinal0 [0x00F876E5+2193125]
# 	Ordinal0 [0x00F911FC+2232828]
# 	BaseThreadInitThunk [0x75A8FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307A6E+238]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument("window-size=1200x600")
# options.headless = True
options.add_argument("--disable-blink-features=AutomationControlled")
# options.headless = False
options.add_argument("window-size=1200x600")
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
# options.headless = False
options.add_argument("--disable-infobars")
# options.add_argument("start-maximized")
options.add_argument("--disable-extensions")    
# options.add_argument("window-size=1200x600")
options.add_argument("test-type")
options.add_argument('--disable-useAutomationExtension')
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
options.add_argument("--disable-xss-auditor")
options.add_argument("--disable-web-security")
options.add_argument("--allow-running-insecure-content")
options.add_argument("--disable-setuid-sandbox")
options.add_argument("--disable-webgl")
options.add_argument("--disable-popup-blocking")
options.add_argument("no-default-browser-check")
options.add_argument("--disable-notifications")
driver = webdriver.Chrome(options=options)
driver.implicitly_wait(30)

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2 import service_account

from selenium.webdriver.support.ui import Select

a = ActionChains(driver)

# driver.get("https://www.attheraces.com/results")

# %%
driver.get("https://www.attheraces.com/results")

# %%
driver.find_element_by_xpath('//header[@class="race-nav__header js-race-nav__header"]').click()
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\2546896567.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//header[@class="race-nav__header js-race-nav__header"]').click()

# %%
previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\2758048711.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")

# %%
previous.click()

# %%
race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_20680\2632651791.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

# %%
race_courses
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="0ae08f3f-f2a2-4ebe-b67a-1d66310f6c46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="3d51fe8c-ee84-4a5a-b08f-c1fbe657ff51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="36dde912-e847-4c7f-b1eb-4f17368e76d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="afbdc184-2cd5-4041-84a2-6d79a8215e07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cc2f6cd9ff8b0a7fe9b9a7d3642febb8", element="cd94cdde-9e9a-4b26-b38a-8a6e1953c946")>]

# %%
data = []
for i,race_course in enumerate(race_courses):
            

    course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text.lower().strip()

    if course_name in interested_courses:

        races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")


        for j,rac in enumerate(races):
            race = rac.find_element_by_tag_name('a').get_attribute('href')
            print(race)
            data.append(race)
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_9960\3077420486.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text.lower().strip()
# C:\Users\alikh\AppData\Local\Temp\ipykernel_9960\3077420486.py:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
# C:\Users\alikh\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1315
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1350
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1425
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1500
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1535
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1610
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1646
# https://www.attheraces.com/racecard/Doncaster/26-March-2022/1716
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1655
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1730
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1800
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1830
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1900
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1930
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/2000
# https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/2030

# %%
data
# Out:
# ['https://www.attheraces.com/racecard/Doncaster/26-March-2022/1315',
#  'https://www.attheraces.com/racecard/Doncaster/26-March-2022/1350',
#  'https://www.attheraces.com/racecard/Doncaster/26-March-2022/1425',
#  'https://www.attheraces.com/racecard/Doncaster/26-March-2022/1500',
#  'https://www.attheraces.com/racecard/Doncaster/26-March-2022/1535',
#  'https://www.attheraces.com/racecard/Doncaster/26-March-2022/1610',
#  'https://www.attheraces.com/racecard/Doncaster/26-March-2022/1646',
#  'https://www.attheraces.com/racecard/Doncaster/26-March-2022/1716',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1655',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1730',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1800',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1830',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1900',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/1930',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/2000',
#  'https://www.attheraces.com/racecard/Wolverhampton/26-March-2022/2030']

# %%
driver.get('https://www.attheraces.com/racecard/Hereford/25-March-2022/1335')

# %%
interested_courses = ['ascot','bangor-on-dee','bath','brighton','chepstow','chester','doncaster','fakenham','ffos las','fontwell','hereford','hexham','lingfield','newcastle','newton abbot','plumpton','ripon','sedgefield','southwell','uttoxeter','windsor','wolverhampton','worcester','yarmouth']

# %%
sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\513907259.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")

# %%
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()

# %%
total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\2304659838.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")

# %%
total_rows
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8e8c70108c1d976945293581be7703d9", element="a3587e58-6c7c-4067-ab15-cd0d50dc19de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8e8c70108c1d976945293581be7703d9", element="4248ae07-66fd-475d-8a33-5fe5d460576e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8e8c70108c1d976945293581be7703d9", element="ae12c71f-e968-45ab-81e3-a19d748ff046")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8e8c70108c1d976945293581be7703d9", element="6abdfc4c-dffd-4751-85f3-7820d6205734")>]

# %%
for k in range(len(total_rows)):
            
    time.sleep(5)
    horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a").text   
    print(horse_name)

    all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
    print(len(all_time))

    inner_list = []
    for s in range(len(all_time)):

        if s<(len(all_time)-3):
            times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
            print(times.text.split('\n')[0])

            if (s == (len(all_time)-4)):
                if (len(all_time)>6):
                    horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                    slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
                    ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                time.sleep(2)

                minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
                if 's' in times.text:
                    seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
                    conv_time = round((minutes*60+seconds),2)
                    print(conv_time)
                else:
                    conv_time = round((minutes*60),2)
                    print(conv_time)
               
            else:
                inner_list.append(times.text.split('\n')[0])
#                         if (s==0):
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\1945726399.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a").text
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\1945726399.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\1945726399.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
# ASHFIELD PADDY
# 13
# 79.64
# 62.60
# 60.86
# 60.09
# 30.26
# 30.25
# 30.50
# 14.19
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\1945726399.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\1945726399.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
#      21     ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
#      22 time.sleep(2)
# ---> 24 minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
#      25 if 's' in times.text:
#      26     seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
#
# ValueError: could not convert string to float: ''

# %%
horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')
ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\3735621771.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\3735621771.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')

# %%
horizontal_bar_width
# Out:
# 445

# %%
driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_17828\3179539142.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//div[@class="js-scrollbar__track-handle scrollbar__track-handle"]')
# <selenium.webdriver.remote.webelement.WebElement (session="8e8c70108c1d976945293581be7703d9", element="079de560-ce9e-44e5-b069-145a7db2393a")>

# %%
all_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="b3aa2889-dcb4-4414-ad73-9750a98b31b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="d1ed24f2-9e7e-403b-b58e-dd277bf1ba84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="be3134b7-6d52-4607-9afb-52b9760161af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="c2e3acc9-cfad-417d-b2eb-d46989ece2ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="9a760cfb-2a06-4e91-8e0b-c150abbf596b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="53d21605-b923-42b1-af6c-5789286ad629")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="20b0e945-d89b-40fd-9a70-87e7e7048894")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="69839d47-f9e2-47e3-ba95-9d8664eefc84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="b9c1dd3e-3e9e-4e78-9820-3098f545dec3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dae3264a1eaffdfb1041f6adc59c20ed", element="0e4b62a6-1d1f-41c3-b863-7054c198c36f")>]

# %%
# driver.maximize_window()

interested_courses = ['ascot','bangor-on-dee','bath','brighton','chepstow','chester','doncaster','fakenham','ffos las','fontwell','hereford','hexham','lingfield','newcastle','newton abbot','plumpton','ripon','sedgefield','southwell','uttoxeter','windsor','wolverhampton','worcester','yarmouth']

# date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
# date_input.click()

# value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
# select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
# driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
# select_month.select_by_visible_text(value1)

# value2 = driver.find_element_by_xpath("//table[@class='pika-table']/tbody/tr/td[7]/button").click()

# a.move_to_element(date_input).perform()
time.sleep(3)
data = []
for day in range(15):
    
    if (day==0):
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
        
    else:
        race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

        for i,race_course in enumerate(race_courses):
            

            course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text.lower().strip()

            if course_name in interested_courses:

                races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")


                for j,rac in enumerate(races):
                    race = rac.find_element_by_tag_name('a').get_attribute('href')
                    print(race)
                    data.append(race)

    driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)

    date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
    a.move_to_element(date_input).perform()

    previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
    previous.click()

    time.sleep(2)

print(data)

comp_data = []

for link in data:
    driver.get(link)
    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
    if 'Sectional Times' in sectional_times.text:
        try:
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()
        except:
            a.move_to_element(driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")).click().perform()
        
        race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
        details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
        racecourse_name = details1[1]
        date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
        print(racecourse_name)
        print(race_time)
        print(date)
        
        total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
        for k in range(len(total_rows)):

            horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a")   
            print(horse_name.text)

            all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
            print(len(all_time))
            for s in range(len(all_time)):
                if s<(len(all_time)-3):
                    times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
                    print(times.text.split('\n')[0])
                    if (s == (len(all_time)-4)):
                        horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                        slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
                        ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                        time.sleep(2)
                        minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
                        seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
                        conv_time = round((minutes*60+seconds),2)
                        print(conv_time)
                        
                        if (s==0):
                            comp_data.append([date,racecourse_name,race_time,horse_name.text,conv_time])
                        else:
                            comp_data.append([date,racecourse_name,race_time,horse_name.text,conv_time])

            all_columns = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[@class='card-header']/div/div")
            print(len(all_columns))
            for m in range(len(all_columns)):
                if m<(len(all_columns)-3):
                    column = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[1]/div/div[{m+4}]")
                    print(column.text)    

        
        print('Sectional Times')
        
        
        
        print("-------------------------------------------------------------")
    print(len(races))
    print(course_name)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument("window-size=1200x600")
options.headless = True
options.add_argument("--disable-blink-features=AutomationControlled")
# options.headless = False
# options.add_argument("window-size=1200x600")
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
# options.headless = False
options.add_argument("--disable-infobars")
options.add_argument("start-maximized")
options.add_argument("--disable-extensions")    
# options.add_argument("window-size=1200x600")
options.add_argument("test-type")
options.add_argument('--disable-useAutomationExtension')
# options.add_experimental_option('useAutomationExtension', False)
# options.add_experimental_option("excludeSwitches", ["enable-logging"])
options.add_argument("--disable-xss-auditor")
options.add_argument("--disable-web-security")
options.add_argument("--allow-running-insecure-content")
options.add_argument("--disable-setuid-sandbox")
options.add_argument("--disable-webgl")
options.add_argument("--disable-popup-blocking")
options.add_argument("no-default-browser-check")
options.add_argument("--disable-notifications")
driver = webdriver.Chrome(options=options)
driver.implicitly_wait(30)
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2 import service_account

from selenium.webdriver.support.ui import Select

a = ActionChains(driver)

driver.get("https://www.attheraces.com/results")

# driver.maximize_window()

interested_courses = ['ascot','bangor-on-dee','bath','brighton','chepstow','chester','doncaster','fakenham','ffos las','fontwell','hereford','hexham','lingfield','newcastle','newton abbot','plumpton','ripon','sedgefield','southwell','uttoxeter','windsor','wolverhampton','worcester','yarmouth']

# date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
# date_input.click()

# value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
# select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
# driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
# select_month.select_by_visible_text(value1)

# value2 = driver.find_element_by_xpath("//table[@class='pika-table']/tbody/tr/td[7]/button").click()

# a.move_to_element(date_input).perform()
time.sleep(3)
data = []
for day in range(15):
    
    if (day==0):
        previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
        previous.click()

        time.sleep(2)
        
    else:
        race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

        for i,race_course in enumerate(race_courses):
            

            course_name = driver.find_element_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/label/span").text.lower().strip()

            if course_name in interested_courses:

                races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")


                for j,rac in enumerate(races):
                    race = rac.find_element_by_tag_name('a').get_attribute('href')
                    print(race)
                    data.append(race)

    driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)

    date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
    a.move_to_element(date_input).perform()

    previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
    previous.click()

    time.sleep(2)

print(data)

comp_data = []

for link in data:
    driver.get(link)
    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
    if 'Sectional Times' in sectional_times.text:
        try:
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()
        except:
            a.move_to_element(driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")).click().perform()
        
        race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
        details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
        racecourse_name = details1[1]
        date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
        print(racecourse_name)
        print(race_time)
        print(date)
        
        total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
        for k in range(len(total_rows)):

            horse_name = driver.find_element_by_xpath(f"//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div[{k+1}]/div/div[3]/div/div/h2/a")   
            print(horse_name.text)

            all_time = driver.find_elements_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div")
            print(len(all_time))
            for s in range(len(all_time)):
                if s<(len(all_time)-3):
                    times = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[{k+1}]/div/div[{s+4}]")
                    print(times.text.split('\n')[0])
                    if (s == (len(all_time)-4)):
                        horizontal_bar_width = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]').rect['width']
                        slider = driver.find_element_by_xpath('//div[@class="js-scrollbar__track scrollbar__track"]')
                        ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/2, 0).release().perform()
                        time.sleep(2)
                        minutes = float(times.text.split('\n')[0].split(' ')[0].replace('m',''))
                        seconds = float(times.text.split('\n')[0].split(' ')[1].replace('s',''))
                        conv_time = round((minutes*60+seconds),2)
                        print(conv_time)
                        
                        if (s==0):
                            comp_data.append([date,racecourse_name,race_time,horse_name.text,conv_time])
                        else:
                            comp_data.append([date,racecourse_name,race_time,horse_name.text,conv_time])

            all_columns = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[@class='card-header']/div/div")
            print(len(all_columns))
            for m in range(len(all_columns)):
                if m<(len(all_columns)-3):
                    column = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[1]/div/div[{m+4}]")
                    print(column.text)    

        
        print('Sectional Times')
        
        
        
        print("-------------------------------------------------------------")
    print(len(races))
    print(course_name)
    
SERVICE_ACCOUNT_FILE = 'keys.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

creds = None
creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)

SAMPLE_SPREADSHEET_ID = '19gNgMJPeriXMJ2mRnBrulMO1apYnBBbBBGHZMhwVF2M'


service = build('sheets', 'v4', credentials=creds)

# Call the Sheets API
sheet = service.spreadsheets()

# Write
request = sheet.values().update(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                            range="Sheet3!A2", valueInputOption="USER_ENTERED", body={"values":comp_data}).execute()
# Out:
# C:\Users\alikh\AppData\Local\Temp\ipykernel_21548\749016586.py:69: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [26], in <cell line: 66>()
#      66 for day in range(15):
#      68     if (day==0):
# ---> 69         previous = driver.find_element_by_xpath("//button[@class='button button--small datepicker__control datepicker__control--prev']")
#      70         previous.click()
#      72         time.sleep(2)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:520, in WebDriver.find_element_by_xpath(self, xpath)
#     498 """
#     499 Finds an element by xpath.
#     500
#    (...)
#     513         element = driver.find_element_by_xpath('//div/td[1]')
#     514 """
#     515 warnings.warn(
#     516     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     517     DeprecationWarning,
#     518     stacklevel=2,
#     519 )
# --> 520 return self.find_element(by=By.XPATH, value=xpath)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:1244, in WebDriver.find_element(self, by, value)
#    1241     by = By.CSS_SELECTOR
#    1242     value = '[name="%s"]' % value
# -> 1244 return self.execute(Command.FIND_ELEMENT, {
#    1245     'using': by,
#    1246     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:424, in WebDriver.execute(self, driver_command, params)
#     422 response = self.command_executor.execute(driver_command, params)
#     423 if response:
# --> 424     self.error_handler.check_response(response)
#     425     response['value'] = self._unwrap_value(
#     426         response.get('value', None))
#     427     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='button button--small datepicker__control datepicker__control--prev']"}
#   (Session info: headless chrome=99.0.4844.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007869A3+2582947]
# 	Ordinal0 [0x0071A6D1+2139857]
# 	Ordinal0 [0x00613A98+1063576]
# 	Ordinal0 [0x0063FF3E+1244990]
# 	Ordinal0 [0x0064013B+1245499]
# 	Ordinal0 [0x00669F52+1417042]
# 	Ordinal0 [0x00658594+1344916]
# 	Ordinal0 [0x0066834A+1409866]
# 	Ordinal0 [0x00658366+1344358]
# 	Ordinal0 [0x00635176+1200502]
# 	Ordinal0 [0x00636066+1204326]
# 	GetHandleVerifier [0x0092BE02+1675858]
# 	GetHandleVerifier [0x009E036C+2414524]
# 	GetHandleVerifier [0x0081BB01+560977]
# 	GetHandleVerifier [0x0081A8D3+556323]
# 	Ordinal0 [0x0072020E+2163214]
# 	Ordinal0 [0x00725078+2183288]
# 	Ordinal0 [0x007251C0+2183616]
# 	Ordinal0 [0x0072EE1C+2223644]
# 	BaseThreadInitThunk [0x75CB6739+25]
# 	RtlGetFullPathName_UEx [0x77078E7F+1215]
# 	RtlGetFullPathName_UEx [0x77078E4D+1165]

# %%
comp_data
# Out:
# [['21 Mar 2022',
#   'Plumpton',
#   '13:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="9e83b591-eb9d-4d97-ad93-bc3aab9a3bd9")>,
#   309.63],
#  ['21 Mar 2022',
#   'Plumpton',
#   '13:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="e6b6b961-83f1-4300-8f60-57002b4f0392")>,
#   310.64],
#  ['21 Mar 2022',
#   'Plumpton',
#   '13:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="16d10df3-b4d1-410a-a15e-1a6eb520258d")>,
#   311.65],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:05',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="fb70a119-a156-4e7d-b1ae-94510e8725c2")>,
#   386.56],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:05',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="a710b5c4-c24a-4412-9664-d78c227f029a")>,
#   387.0],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:05',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="72d7a276-df92-4ad8-8b4d-9f08bf3fbc02")>,
#   388.68],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:05',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="63e9eca7-69ed-41a5-a162-4ac07ea42a06")>,
#   389.62],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:40',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="93f562b2-5431-43fa-8e73-67f5075de0b9")>,
#   390.51],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:40',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="03a5ee2c-a903-4def-8c57-accf0fe1f349")>,
#   390.9],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:40',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="bcb80a1c-a6b9-4be2-a946-ab5b0132945a")>,
#   390.94],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:40',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="48f784b6-09b7-4fdc-8507-e8ca8da6795c")>,
#   398.14],
#  ['21 Mar 2022',
#   'Plumpton',
#   '15:40',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ea053bbe-d464-48f2-a14e-3e69466a2c97")>,
#   400.75],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="d6c6763b-db81-4fd9-b2c3-7b424f166fda")>,
#   400.6],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6380941c-26cc-45d8-8062-ddbb41e30fa1")>,
#   402.42],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="fd266ea5-8df6-4e73-8926-5f08be54d6de")>,
#   405.14],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="bc1548d1-f073-40b8-acdf-398199808cb2")>,
#   407.29],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8eb312b7-1aad-4e31-a587-45880fc457ed")>,
#   236.18],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="9a19695b-ee0c-477d-b282-f3c7150349dc")>,
#   236.4],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="45d77def-e066-47f7-a6c8-ae52fcceb7ce")>,
#   236.7],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="da027376-fa36-4f12-ae3a-153965bdd45e")>,
#   237.5],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="523c7599-7d3e-4af4-90ed-94b0c019a143")>,
#   237.89],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="046db2f0-de8a-4c19-862f-fb4e82e99010")>,
#   238.75],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="2ad2542c-aa43-40c4-bfb1-3108f126526b")>,
#   239.52],
#  ['21 Mar 2022',
#   'Plumpton',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8304cdc8-a92e-4cc7-b35a-ddf0afb6a4a6")>,
#   244.32],
#  ['21 Mar 2022',
#   'Southwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ea3dfc11-5f39-4221-990e-e7c693302c39")>,
#   252.61],
#  ['21 Mar 2022',
#   'Southwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="7ce98e10-6983-4bc9-96cb-771c2b868e14")>,
#   254.96],
#  ['21 Mar 2022',
#   'Southwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8b8d9821-f4d8-4e65-92ba-1e79357fce05")>,
#   256.3],
#  ['21 Mar 2022',
#   'Southwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8c9937cb-f5fc-45d8-b260-0a6383985f86")>,
#   258.63],
#  ['21 Mar 2022',
#   'Southwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="3bc4bfcf-a55d-40be-a1c4-c5b001505f00")>,
#   259.79],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="d7d494b6-a400-4d34-ae0d-354034fe9187")>,
#   240.86],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="72549b64-4985-4c28-af62-2a3b588d3b2e")>,
#   241.05],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="83fd48ea-1aaf-452b-b59e-eed0d3108a93")>,
#   241.18],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="1bc8761c-b6e2-4fae-a196-1c789944970a")>,
#   241.22],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="022163e7-c3c2-4927-b8f7-066306ba96d6")>,
#   241.34],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="f9444462-8e4e-4e89-bfd3-633c26545ca0")>,
#   242.17],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ffabc4b3-4091-48a0-9e91-93f8df83bb9f")>,
#   242.62],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8c3629e5-8212-46ef-b116-e2b89898ea28")>,
#   243.09],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="64cb709d-c5b7-4d85-bd37-8c17010b778d")>,
#   245.61],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="4bec3554-aa97-4556-a9b8-e77187e1c305")>,
#   249.57],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="5e2f4556-8762-4f6b-90ce-0bcde09dc4af")>,
#   255.19],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="f41993d3-4eb7-45ed-9289-eef39e763916")>,
#   325.01],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="41529e70-e382-463b-ab78-614677f7bc40")>,
#   325.69],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="131c3c29-13df-4a07-b0c5-014470071fca")>,
#   326.03],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="abb6b48c-2fa0-4fea-9cf5-3fac50409ac4")>,
#   326.87],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="2c3ca6e8-329f-49c8-bb02-92137ed0df78")>,
#   328.65],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="551032f1-c418-4274-8413-77c4af721a45")>,
#   328.78],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="edef1b8b-e2c7-4938-a1b8-4f71d67024a8")>,
#   329.82],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8beba054-981e-4c15-ba24-74db2b50ad05")>,
#   330.41],
#  ['21 Mar 2022',
#   'Southwell',
#   '14:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ba062336-0562-4157-accf-7976161e69ab")>,
#   330.44],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ca8ca959-7970-4f36-9c86-13a757b31049")>,
#   247.61],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="42ee6a89-ec6f-4ecf-80ef-a25a447e3c60")>,
#   250.6],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8acdcbb4-88db-48ee-b124-bf6fe0c74726")>,
#   250.61],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="27aef61d-4e7e-4ea1-be15-e823dc4b46c2")>,
#   251.91],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="4349f77c-be86-4abf-8cec-cd72fd394728")>,
#   252.73],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ea38fb66-73f8-4286-9a5d-82bb8439a9ae")>,
#   253.14],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6d6a574b-21cf-4fde-bf37-b626bb90de73")>,
#   324.55],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="971d3f39-4ecd-47b0-b5b5-ad6fec5f9b01")>,
#   324.64],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="2263a694-d7ee-49e5-8afc-c19012962b7e")>,
#   324.83],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="5e4d9e93-23d0-4dc9-9c3c-f12bbf201960")>,
#   325.05],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="aa2410f8-27b3-4437-88fb-e00fd0aa5e43")>,
#   325.95],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6e37fca3-e44b-47d2-87e6-b42a9b0abe5c")>,
#   327.37],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="7bb91eaf-6a79-4d9b-9e5d-3cdd06697300")>,
#   328.68],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="58069196-cf41-4818-917a-6246b74b0828")>,
#   329.49],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="4ac69252-44c2-4440-b43a-8245740c7c99")>,
#   329.56],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="f8a4b584-ca38-4887-80b5-2ce0ab179eb9")>,
#   329.84],
#  ['21 Mar 2022',
#   'Southwell',
#   '15:55',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="938ef6e9-90cc-4155-b10d-37021e53225b")>,
#   332.97],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:00',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="fadbd3ef-1b15-4163-9a74-0844c6142f54")>,
#   295.93],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:00',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="73bea132-0748-40ba-8144-3637f7a67fa8")>,
#   296.07],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:00',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="14c762fc-7f7b-4f58-8a97-71fd6a3b82ad")>,
#   296.07],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:00',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6221c651-1a83-4cd2-9127-49bf79d6bc22")>,
#   300.49],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:30',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="c12f5acf-c133-47d8-a96e-1ed97a7e657e")>,
#   380.16],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:30',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="c2e11fc6-69bd-40e9-a240-3e89d9a3df8c")>,
#   382.75],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:30',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="dcc1b8b6-6c4d-4393-9823-49ed97f32002")>,
#   384.72],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:30',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="97c520c5-54dd-465b-bfc9-53eaf634c47c")>,
#   388.68],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:30',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="d5b6958d-caca-4683-97eb-fad118c9785e")>,
#   389.44],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:30',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ab57f2c4-e6fe-4f26-a4b8-182d0fd69338")>,
#   390.33],
#  ['20 Mar 2022',
#   'Chepstow',
#   '14:30',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="e2070096-283a-4e6d-856c-d5601acb36a6")>,
#   401.33],
#  ['20 Mar 2022',
#   'Chepstow',
#   '15:05',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="3c58e9b5-f4c8-4b84-b4e4-db299b958c2b")>,
#   378.96],
#  ['20 Mar 2022',
#   'Chepstow',
#   '15:05',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="574cc497-f5a5-4030-99dd-8ae91a0d2b1f")>,
#   379.67],
#  ['20 Mar 2022',
#   'Chepstow',
#   '15:05',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="4eaf69eb-dfd7-49dc-ab19-136c3d54ae2f")>,
#   383.06],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="b4c2e812-9086-454e-8526-2327829fa860")>,
#   295.44],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="7678fdf8-533c-4508-bdd0-f9102795c70d")>,
#   296.33],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="5ea8b42f-5251-4552-b96e-779637b79c71")>,
#   297.7],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="7bba09bb-59b9-45f2-b240-e44b5b34266d")>,
#   299.84],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="3450a93b-d555-4eba-bf2d-4de1b039dd67")>,
#   306.93],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="5cee981d-3707-4f3d-a614-9b035b9c44e0")>,
#   307.54],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="c3949c82-48e8-4315-869d-d7dbfde5a778")>,
#   307.68],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="51b914cb-adbf-46cc-ad40-36e4f372cdd0")>,
#   308.61],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="f1c7570d-5f6f-47db-a2ec-ee684e2cd819")>,
#   310.99],
#  ['20 Mar 2022',
#   'Chepstow',
#   '16:45',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="c952baac-65b6-4bba-bfcb-b76af4d2f218")>,
#   319.37],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="674ee791-50e4-45fb-a1d3-3504007b44d9")>,
#   238.29],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="18e44cbf-babc-447a-b95e-2743fee54599")>,
#   239.06],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="299669cf-13c1-47a4-9d17-a06cdc42257b")>,
#   240.1],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="1d955d24-e052-415a-98d1-72ec5075e1c5")>,
#   241.18],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="64763257-f1cd-4574-a932-7ccc666cf0c4")>,
#   241.77],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="9e2f662e-d591-49ce-9241-38393485bddb")>,
#   248.83],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="61644873-d517-4d10-8a77-882654b21192")>,
#   249.33],
#  ['20 Mar 2022',
#   'Chepstow',
#   '17:15',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="c0ddaaf9-4a01-444a-9058-63d25cb40d13")>,
#   254.72],
#  ['19 Mar 2022',
#   'Fontwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="2dd13976-3f43-4039-80e7-33178324b13f")>,
#   261.2],
#  ['19 Mar 2022',
#   'Fontwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="be92606b-f4d4-464f-b8ae-695737df3908")>,
#   267.77],
#  ['19 Mar 2022',
#   'Fontwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="4d79044f-436d-4a70-b36f-9e4d3da29283")>,
#   268.69],
#  ['19 Mar 2022',
#   'Fontwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="abf53415-b3c1-4296-996a-ca91c4989139")>,
#   270.99],
#  ['19 Mar 2022',
#   'Fontwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="27c56933-097d-4d42-9428-0bda4c73554c")>,
#   271.25],
#  ['19 Mar 2022',
#   'Fontwell',
#   '13:35',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="0935748e-6ada-4934-8987-fd2c4edb3674")>,
#   273.09],
#  ['19 Mar 2022',
#   'Fontwell',
#   '14:11',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="2888e287-9b3c-4b0d-bd54-3b990c87396d")>,
#   345.84],
#  ['19 Mar 2022',
#   'Fontwell',
#   '14:11',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="dec51763-316b-461c-8a5a-9f6521bafab4")>,
#   350.82],
#  ['19 Mar 2022',
#   'Fontwell',
#   '14:46',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ef39971b-407f-49d3-a9c6-c423a533284b")>,
#   338.97],
#  ['19 Mar 2022',
#   'Fontwell',
#   '14:46',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="30d6ee3d-61a1-4602-ae68-1223f77ecf69")>,
#   342.81],
#  ['19 Mar 2022',
#   'Fontwell',
#   '14:46',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="95c67dd0-74ba-493b-ad51-4d90c9343453")>,
#   345.04],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ba92983d-be46-46d8-a6ff-0359a108deb4")>,
#   288.45],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="16c2e276-2139-420b-9eae-a309c9076cc3")>,
#   290.31],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="7c9689ef-7620-45dd-ba0c-ce6e228b9960")>,
#   290.57],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="725db37e-28f2-40b3-a04b-e7e9367ab81d")>,
#   291.01],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="fd4f5cb9-1bbb-42aa-8ac8-9694aa5fd165")>,
#   294.72],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="5ea79f41-9f74-41c3-9438-79ab5ce2bcdd")>,
#   295.58],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6c36a11a-f1e8-4a68-bcc7-a3df8f80efc8")>,
#   295.74],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8f0fd0bf-35e7-405a-aafa-8ac6113ecddf")>,
#   298.4],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:21',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="27ddd954-4fe3-40e2-bdfa-ffb7472b71a3")>,
#   303.1],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:56',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="015d2371-ad25-40d6-9afd-854decf04dde")>,
#   278.75],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:56',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="e4845624-53a6-4b2a-823a-902a58dd9bae")>,
#   279.06],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:56',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="aacc937b-37d5-4ae2-826f-7b3a634976e7")>,
#   280.57],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:56',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="88f27b9a-0788-440b-aa39-e5def58c5320")>,
#   283.68],
#  ['19 Mar 2022',
#   'Fontwell',
#   '15:56',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="978b7ace-ecc8-46e5-9f61-5e16ac5637cf")>,
#   293.21],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="dc7ddb7f-9c6a-4f9e-a023-d7b26d5a933e")>,
#   400.93],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="712429bc-7475-4f65-a089-4cab68ac45c4")>,
#   401.17],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="1efee2ed-d102-4d51-87dd-b16dada7195a")>,
#   401.46],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="3010eeca-48e2-4c26-b76a-b887b5c626a1")>,
#   403.27],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="88189d34-8635-4e7d-93ba-4d564ed949ee")>,
#   406.22],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="8bb6c0dc-6337-4704-b3ef-11314af5b9d3")>,
#   406.43],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="4fc5009d-39c9-4596-b3ba-03f887d21a1a")>,
#   413.21],
#  ['19 Mar 2022',
#   'Fontwell',
#   '16:31',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="b3d5e60c-8cf6-4f53-bc0c-75eb02eb2429")>,
#   418.79],
#  ['19 Mar 2022',
#   'Newcastle',
#   '13:58',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="901bfc7e-d3b8-42a6-a717-a47dbd2a0f38")>,
#   244.55],
#  ['19 Mar 2022',
#   'Newcastle',
#   '13:58',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="9b2ac95d-6953-4673-93f5-4bffacfa1ddc")>,
#   245.92],
#  ['19 Mar 2022',
#   'Newcastle',
#   '13:58',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="b8d7ca6b-8da0-47bd-a22e-1e53ebc78953")>,
#   246.56],
#  ['19 Mar 2022',
#   'Newcastle',
#   '13:58',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6cf4a2d7-939f-4d85-94de-4d51c19e637c")>,
#   253.67],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="0828af15-8756-4fb6-8f18-f86ce9ecac79")>,
#   312.09],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="98ef6645-4a2e-4a87-ab0f-d57b0cbc4b37")>,
#   312.34],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="3bb659e3-2e82-4336-bf4e-15d84ca9766d")>,
#   312.92],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="58e3f222-338f-4686-bde6-1eadedc6616b")>,
#   314.21],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="1b3260ea-3d61-4ce6-8355-f030ea32a25b")>,
#   315.28],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="0acad760-b53f-48ae-8d99-0f5fdb17a7d0")>,
#   316.8],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="0f3b2d69-a5a0-49b2-845d-ea1651747e9a")>,
#   320.11],
#  ['19 Mar 2022',
#   'Newcastle',
#   '14:33',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6ca31a7f-8c0c-4948-8215-f9cd67e1f82e")>,
#   324.4],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="c2d6a3b0-98cf-477a-8768-0cb7bb54105a")>,
#   235.73],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6b49b975-0091-4a97-9c1d-0db923802fc9")>,
#   236.31],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="64b4409a-124f-4113-b373-9412e488bb58")>,
#   238.16],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:10',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="11ce9c8d-c3f1-4876-b100-c75f482732e4")>,
#   242.11],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:43',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="fd5eddb3-e2ac-4cee-80cc-652e664f5197")>,
#   329.54],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:43',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="cce9581c-2d78-4f19-97b0-440aa3c1d46f")>,
#   331.01],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:43',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="bde25284-919d-4952-b805-2b8a0cd6758e")>,
#   332.51],
#  ['19 Mar 2022',
#   'Newcastle',
#   '15:43',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="15dd6495-1cdc-4937-9a9f-93e0ee686024")>,
#   334.8],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="6b1ea17f-456a-4e02-bee7-b9e9cdf7085e")>,
#   302.07],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="0c1384c0-dea8-426d-8133-db03074bda18")>,
#   302.59],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="c4ba7efc-c4e5-47c7-b320-72efdb6d3b1c")>,
#   302.65],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="39058e5c-dfb0-4aa0-9df8-32ff967fb525")>,
#   302.77],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="5c944710-a7bd-4ed7-b2b9-4edcfe483d3b")>,
#   304.35],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="b14b132f-9a4f-44ed-b3e6-b5f9c6f8b13f")>,
#   305.61],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="1ae8e729-d082-4f17-b45f-d2bfc1b47f1f")>,
#   305.64],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="32806640-df5b-46a8-90cc-17740630fcaf")>,
#   306.02],
#  ['19 Mar 2022',
#   'Newcastle',
#   '16:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="523273e9-556a-46f6-8f35-0a8aadd5f3e8")>,
#   307.24],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="109a3730-8260-4da3-a780-dde69733ce98")>,
#   302.5],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="3682b072-c17a-4ce0-a255-eba3da99b38b")>,
#   303.67],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="ca19e9c5-ce86-4c66-a663-92d47b3227c9")>,
#   304.23],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="01a1560b-2f6c-4b4b-8cbc-c2778c29f8c5")>,
#   310.82],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:20',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="80420cd8-e7c1-4c53-9d6c-522e62c563c6")>,
#   312.58],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="22ec8fc2-5afe-444e-bf78-be1cb3b434ee")>,
#   347.3],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="978e5758-cad5-4c11-85bf-2514ae02ffe7")>,
#   348.88],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="93667f26-914b-4e4a-a181-3dc9ecaed477")>,
#   352.84],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="92e9d03f-7bdc-49f8-a4e3-5d1bccf5ab85")>,
#   356.96],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="77db3be3-52e1-4035-8f0a-6c2ba1d48617")>,
#   357.36],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="7599c74c-c900-4385-937c-f7fac2c4b5e4")>,
#   359.39],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '13:50',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="1f80d7d5-d1c7-4686-b66e-fc69c8b89f9e")>,
#   365.03],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '14:25',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="3621046f-6342-4646-9b9b-ec8b308a1ffa")>,
#   380.45],
#  ['19 Mar 2022',
#   'Uttoxeter',
#   '14:25',
#   <selenium.webdriver.remote.webelement.WebElement (session="07dba46585f575c3219a008c1da6be5b", element="28ad2290-cbc6-4477-987b-d76e66556bb2")>,
#   381.2]]

# %%
data
# Out:
# []

# %%
if WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click():
    print('hamza')

# %%
ele = WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")))

# %%
a.move_to_element(ele).click().perform()

# %%
 if (WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")))):
    print("hamza")
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 if (WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")))):
#       2    print("hamza")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\support\wait.py:89, in WebDriverWait.until(self, method, message)
#      87     if time.time() > end_time:
#      88         break
# ---> 89 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007869A3+2582947]
# 	Ordinal0 [0x0071A6D1+2139857]
# 	Ordinal0 [0x00613A98+1063576]
# 	Ordinal0 [0x0063FF3E+1244990]
# 	Ordinal0 [0x0064013B+1245499]
# 	Ordinal0 [0x00669F52+1417042]
# 	Ordinal0 [0x00658594+1344916]
# 	Ordinal0 [0x0066834A+1409866]
# 	Ordinal0 [0x00658366+1344358]
# 	Ordinal0 [0x00635176+1200502]
# 	Ordinal0 [0x00636066+1204326]
# 	GetHandleVerifier [0x0092BE02+1675858]
# 	GetHandleVerifier [0x009E036C+2414524]
# 	GetHandleVerifier [0x0081BB01+560977]
# 	GetHandleVerifier [0x0081A8D3+556323]
# 	Ordinal0 [0x0072020E+2163214]
# 	Ordinal0 [0x00725078+2183288]
# 	Ordinal0 [0x007251C0+2183616]
# 	Ordinal0 [0x0072EE1C+2223644]
# 	BaseThreadInitThunk [0x75CB6739+25]
# 	RtlGetFullPathName_UEx [0x77078E7F+1215]
# 	RtlGetFullPathName_UEx [0x77078E4D+1165]

# %%
all_columns = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[@class='card-header']/div/div")
print(len(all_columns))
for m in range(len(all_columns)):
    if m<(len(all_columns)-3):
        column = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[1]/div/div[{m+4}]")
        print(column.text)
# Out:
# 12
#
# 16f-12f
# 12f-8f
# 8f-6f
# 6f-4f
# 4f-2f
# 2f-1f
# 1f-Finish
# Finish

# %%
total_rows = driver.find_elements_by_xpath("//div[@class='card card-column__fixed js-card-column__fixed']/div[2]/div")
print(len(total_rows))
# Out:
# 4

# %%
# all_time = driver.find_elements_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[1]/div/div")
# print(len(all_time))
# for s in range(len(all_time)):
#     if s<(len(all_time)-3):
#         time = driver.find_element_by_xpath(f"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div[1]/div/div[{s+4}]")
#         print(time.text)
        
minutes = driver.find_element_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div/div/div[-1]/div/div").text   
#  = int(time.split(":")[0])
# add = float(time.split(":")[1])
# conv_time = round((minutes*60+add),2)
print(minutes)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-43-73f890e5a3d5> in <module>
#       6 #         print(time.text)
#       7
# ----> 8 minutes = driver.find_element_by_xpath("//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div/div/div[-1]/div/div").text
#       9 #  = int(time.split(":")[0])
#      10 # add = float(time.split(":")[1])
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     482         """
#     483         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 484         return self.find_element(by=By.XPATH, value=xpath)
#     485
#     486     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1151             value = '[name="%s"]' % value
#    1152
# -> 1153         return self.execute(Command.FIND_ELEMENT, {
#    1154             'using': by,
#    1155             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     398         response = self.command_executor.execute(driver_command, params)
#     399         if response:
# --> 400             self.error_handler.check_response(response)
#     401             response['value'] = self._unwrap_value(
#     402                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     234                 alert_text = value['alert'].get('text')
#     235             raise exception_class(message, screen, stacktrace, alert_text)
# --> 236         raise exception_class(message, screen, stacktrace)
#     237
#     238     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='scrollbar__content js-scrollbar__content']/div[2]/div/div/div[-1]/div/div"}
#   (Session info: chrome=99.0.4844.74)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003C9943+2595139]
# 	Ordinal0 [0x0035C9F1+2148849]
# 	Ordinal0 [0x00254528+1066280]
# 	Ordinal0 [0x00280FD4+1249236]
# 	Ordinal0 [0x002811CB+1249739]
# 	Ordinal0 [0x002AD812+1431570]
# 	Ordinal0 [0x0029BA34+1358388]
# 	Ordinal0 [0x002ABAF2+1424114]
# 	Ordinal0 [0x0029B806+1357830]
# 	Ordinal0 [0x00276086+1204358]
# 	Ordinal0 [0x00276F96+1208214]
# 	GetHandleVerifier [0x0056B232+1658114]
# 	GetHandleVerifier [0x0062312C+2411516]
# 	GetHandleVerifier [0x0045F261+560433]
# 	GetHandleVerifier [0x0045E366+556598]
# 	Ordinal0 [0x0036286B+2173035]
# 	Ordinal0 [0x003675F8+2192888]
# 	Ordinal0 [0x003676E5+2193125]
# 	Ordinal0 [0x003711FC+2232828]
# 	BaseThreadInitThunk [0x762FFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77157A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77157A6E+238]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains

driver = webdriver.Chrome(r"C:\Users\USER\Documents\Scraping_waghera\chromedriver.exe")

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.support.ui import Select

a = ActionChains(driver)

driver.get("https://www.attheraces.com/results")
driver.implicitly_wait(10)
driver.maximize_window()

interested_courses = ['Ascot','Bangor-on-dee','Bath','Brighton','Chepstow','Chester','Doncaster','Fakenham','Ffos las','Fontwell','Hereford','Hexham','Lingfield','Newcastle','Newton abbot','Plumpton','Ripon','Sedgefield','Southwell','Uttoxeter','Windsor','Wolverhampton','Worcester','Yarmouth']

date_input = driver.find_element_by_xpath("//input[@id='race-nav-datepicker']")
date_input.click()

value1 = driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']/option[3]").text
select_month = Select(driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']"))
driver.find_element_by_xpath("//select[@class='pika-select pika-select-month']").click()
select_month.select_by_visible_text(value1)

value2 = driver.find_element_by_xpath("//table[@class='pika-table']/tbody/tr/td[7]/button").click()

a.move_to_element(date_input).perform()
time.sleep(3)
race_courses = driver.find_elements_by_xpath("//div[@id='tab-race-nav--uk']/div/div/div/div/div")

data = []
for i,race_course in enumerate(race_courses):
    
    races = driver.find_elements_by_xpath(f"//div[@id='tab-race-nav--uk']/div/div/div/div/div[{i+1}]/div/div/ul/li")
    for k in races:
        print(k.find_element_by_tag_name('a').get_attribute('href'))
        data.append(k.find_element_by_tag_name('a').get_attribute('href'))
        
for j in data:
    driver.get(j)
    sectional_times = driver.find_element_by_xpath("//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a")
    if 'Sectional Times' in sectional_times.text:
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='tabs__links tabs__links--grey js-tabs__links']/li[2]/a"))).click()
#         sectional_times.click()
        total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
        all_times = driver.find_elements_by_xpath('//div[@class="card card-column__fixed js-card-column__fixed"]/div[@class="card-body"]/div[@class="card-entry"]')
        time_name_date = driver.find_element_by_xpath('//div[@class="race-header__details race-header__details--primary"]/h2').text
        all_colu = driver.find_elements_by_xpath('//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"]')
        print(time_name_date)
        for i,j in enumerate(all_times):
            horse = driver.find_element_by_xpath(f'//div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div[3]/div/div/h2/a').text
            print(horse)
            inner_ele = driver.find_elements_by_xpath(f'//div[@class="scrollbar__content js-scrollbar__content"]/div[@class="card-body"]/div[@class="card-entry"][{i+1}]/div/div')
            for k in inner_ele:
                if k.text == '':
                    continue
                print(k.text)
            print('\n')
        print('Sectional Times')
        print('***********')
# Out:
# <ipython-input-5-d442b550e22b>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\USER\Documents\Scraping_waghera\chromedriver.exe")
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1310
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1345
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1420
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1455
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1530
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1605
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1640
# https://www.attheraces.com/racecard/Huntingdon/06-March-2022/1710
# https://www.attheraces.com/racecard/Leopardstown/06-March-2022/1355
# https://www.attheraces.com/racecard/Leopardstown/06-March-2022/1430
# https://www.attheraces.com/racecard/Leopardstown/06-March-2022/1505
# https://www.attheraces.com/racecard/Leopardstown/06-March-2022/1540
# https://www.attheraces.com/racecard/Leopardstown/06-March-2022/1615
# https://www.attheraces.com/racecard/Leopardstown/06-March-2022/1650
# https://www.attheraces.com/racecard/Leopardstown/06-March-2022/1720
# https://www.attheraces.com/racecard/Sedgefield/06-March-2022/1300
# https://www.attheraces.com/racecard/Sedgefield/06-March-2022/1330
# https://www.attheraces.com/racecard/Sedgefield/06-March-2022/1403
# https://www.attheraces.com/racecard/Sedgefield/06-March-2022/1438
# https://www.attheraces.com/racecard/Sedgefield/06-March-2022/1513
# https://www.attheraces.com/racecard/Sedgefield/06-March-2022/1548
# https://www.attheraces.com/racecard/Sedgefield/06-March-2022/1623
# https://www.attheraces.com/racecard/Wexford/06-March-2022/1410
# https://www.attheraces.com/racecard/Wexford/06-March-2022/1445
# https://www.attheraces.com/racecard/Wexford/06-March-2022/1520
# https://www.attheraces.com/racecard/Wexford/06-March-2022/1555
# https://www.attheraces.com/racecard/Wexford/06-March-2022/1630
# https://www.attheraces.com/racecard/Wexford/06-March-2022/1700
# https://www.attheraces.com/racecard/Wexford/06-March-2022/1730
# 13:00 Sedgefield 06 Mar 2022
#
# 76.12
# FRONT
# 61.09
# FRONT
# 29.27
# FRONT
# 30.03
# FRONT
# 28.89
# FRONT
# 14.34
# FRONT
# 16.88
# FRONT
# 4m 16.61s
#
#
# BAY OF INTRIGUE
# 77.09
# 61.03
# 29.00
# 29.88
# 29.18
# 14.27
# 16.76
# 4m 17.21s
#
#
# LIGHTNING ATTACK
# 76.08
# FRONT
# 61.17
# FRONT
# 29.14
# FRONT
# 30.11
# FRONT
# 29.00
# 14.70
# 17.60
# 4m 17.81s
#
#
# BEAT BOX
# 76.72
# 61.34
# 29.11
# 30.26
# 30.18
# 14.39
# 16.00
# 4m 17.99s
#
#
# SILKSTONE
# 76.51
# 61.04
# 29.33
# 29.99
# 29.10
# 14.92
# 17.21
# 4m 18.10s
#
#
# DERRACRIN
# 77.03
# 61.33
# 29.03
# 30.25
# 30.03
# 15.11
# 17.09
# 4m 19.87s
#
#
# ROBEAM
# 76.74
# 61.24
# 29.29
# 31.05
# REAR
# 30.63
# 14.81
# 17.01
# 4m 20.78s
#
#
# BURNAGE BOY
# 77.19
# REAR
# 61.37
# REAR
# 29.03
# REAR
# 30.69
# REAR
# 30.95
# REAR
# 14.83
# REAR
# 18.04
# REAR
# 4m 22.11s
#
#
# Sectional Times
# ***********
# 13:30 Sedgefield 06 Mar 2022
#
# 125.67
# 62.79
# 29.69
# 29.99
# 27.50
# FRONT
# 13.34
# FRONT
# 15.44
# FRONT
# 5m 4.44s
#
#
# WHERE'S HECTOR
# 126.08
# 62.83
# 29.58
# 29.99
# 28.43
# 13.92
# 15.65
# 5m 6.47s
#
#
# PATAGONIA
# 125.05
# FRONT
# 63.19
# FRONT
# 29.72
# FRONT
# 29.87
# FRONT
# 28.38
# 14.42
# 16.39
# 5m 7.03s
#
#
# ZWICKY
# 126.43
# REAR
# 62.68
# REAR
# 29.42
# REAR
# 30.27
# 29.61
# 14.60
# 17.83
# 5m 10.85s
#
#
# CHASE OUTLAW
# 125.63
# 62.93
# 29.66
# 30.35
# 30.45
# 15.45
# 18.97
# 5m 13.43s
#
#
# LISLORAN
# 126.26
# 62.79
# REAR
# 29.57
# REAR
# 30.64
# REAR
# 31.91
# REAR
# 15.18
# REAR
# 17.98
# REAR
# 5m 14.33s
#
#
# Sectional Times
# ***********
# 14:03 Sedgefield 06 Mar 2022
#
#
# 115.84
# 68.07
# 66.50
# 64.32
# 30.83
# 33.90
# 33.87
# FRONT
# 14.75
# FRONT
# 18.08
# FRONT
#
#
# MORNINGSIDE
# 116.08
# REAR
# 68.08
# REAR
# 66.38
# REAR
# 64.38
# REAR
# 30.67
# 33.50
# FRONT
# 34.39
# 14.95
# 18.11
#
#
# SHARP RESPONSE
# 115.46
# 68.24
# 65.94
# FRONT
# 64.14
# FRONT
# 31.20
# FRONT
# 34.12
# FRONT
# 36.12
# 15.84
# 20.60
#
#
# CHEF D'OEUVRE
# 115.21
# FRONT
# 68.13
# FRONT
# 66.70
# 64.06
# 31.37
# 35.14
# 36.41
# 15.51
# 19.36
# REAR
#
#
# CHIDSWELL
# 116.05
# REAR
# 68.07
# REAR
# 66.40
# REAR
# 64.49
# REAR
# 31.63
# REAR
# 35.67
# REAR
# 35.78
# REAR
# 14.89
# REAR
# 18.92
# REAR
#
#
# Sectional Times
# ***********
# 14:38 Sedgefield 06 Mar 2022
#
# 121.84
# 65.81
# 66.93
# 65.90
# 29.50
# 29.60
# FRONT
# 27.59
# FRONT
# 13.73
# FRONT
# 15.63
# FRONT
#
#
# BIRD ON THE WIRE
# 121.66
# 65.80
# 67.07
# 65.94
# 29.53
# 29.96
# 27.78
# 13.52
# 15.41
#
#
# MIDNIGHT MARY
# 121.74
# 65.64
# 66.88
# FRONT
# 65.82
# FRONT
# 29.74
# FRONT
# 29.77
# FRONT
# 28.01
# 13.78
# 15.43
#
#
# THATBEATSBANAGHER
# 121.98
# 65.89
# 66.93
# 65.70
# 29.71
# 29.94
# 27.98
# 13.73
# 16.02
#
#
# LATE DATE
# 121.29
# FRONT
# 65.96
# FRONT
# 67.04
# FRONT
# 65.82
# FRONT
# 29.61
# FRONT
# 29.83
# FRONT
# 28.23
# 14.21
# 18.40
#
#
# TANORA
# 122.14
# REAR
# 66.13
# REAR
# 66.79
# REAR
# 65.93
# REAR
# 29.43
# REAR
# 29.92
# REAR
# 28.41
# REAR
# 14.46
# REAR
# 19.73
# REAR
#
#
# Sectional Times
# ***********
# 15:13 Sedgefield 06 Mar 2022
#
# 88.32
# REAR
# 69.66
# 67.33
# 30.41
# 30.50
# FRONT
# 30.50
# FRONT
# 14.07
# FRONT
# 16.67
# FRONT
#
#
# THE KING OF MAY
# 88.30
# 69.74
# 67.42
# 31.01
# 30.87
# 29.86
# 14.05
# 18.17
#
#
# THE PADDY PIE
# 87.76
# FRONT
# 69.54
# FRONT
# 67.63
# FRONT
# 30.57
# FRONT
# 30.72
# FRONT
# 31.31
# 14.73
# 19.05
#
#
# TONTO'S SPIRIT
# 87.83
# FRONT
# 69.69
# 67.86
# 31.58
# 32.75
# 31.37
# 14.88
# 17.19
#
#
# MANWELL
# 88.41
# REAR
# 69.89
# REAR
# 67.45
# REAR
# 31.91
# REAR
# 32.92
# REAR
# 34.53
# REAR
# 15.98
# REAR
# 25.66
# REAR
#
#
# Sectional Times
# ***********
# 15:48 Sedgefield 06 Mar 2022
#
# 121.66
# 64.45
# 30.12
# 30.54
# FRONT
# 28.00
# FRONT
# 13.83
# FRONT
# 15.76
# FRONT
# 5m 4.37s
#
#
# ZAFAR
# 121.48
# FRONT
# 63.84
# FRONT
# 30.68
# FRONT
# 30.83
# FRONT
# 29.12
# 14.27
# 16.51
# 5m 6.71s
#
#
# MASON JAR
# 124.94
# 62.63
# 29.31
# 31.14
# 29.34
# 14.31
# 15.90
# 5m 7.56s
#
#
# LE GRAND VERT
# 125.10
# 62.54
# 29.73
# 30.90
# 30.17
# 15.29
# 17.09
# 5m 10.81s
#
#
# TWOSHOTSOFTEQUILA
# 125.16
# 62.62
# 28.80
# 30.44
# 29.94
# 15.06
# 19.07
# 5m 11.09s
#
#
# PERFECT MAN
# 125.64
# REAR
# 62.27
# REAR
# 30.41
# REAR
# 31.91
# REAR
# 31.55
# REAR
# 15.31
# REAR
# 18.49
# REAR
# 5m 15.59s
#
#
# Sectional Times
# ***********
# 16:23 Sedgefield 06 Mar 2022
#
# 84.83
# 67.38
# FRONT
# 64.40
# 30.66
# 30.49
# FRONT
# 31.73
# FRONT
# 14.91
# FRONT
# 18.37
# FRONT
#
#
# CROAGH PATRICK
# 84.55
# FRONT
# 67.64
# FRONT
# 63.82
# FRONT
# 30.94
# FRONT
# 31.25
# 31.80
# 14.54
# 18.56
#
#
# OCEANS RED
# 85.09
# 67.21
# 64.06
# 30.50
# FRONT
# 31.53
# 34.54
# 16.95
# 20.88
#
#
# KNOCKNAMONA
# 85.89
# REAR
# 67.94
# REAR
# 65.42
# REAR
# 31.85
# REAR
# 32.35
# REAR
# 34.70
# REAR
# 16.47
# REAR
# 21.02
# REAR
#
#
# Sectional Times
# ***********

# %%
total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
for k in range(int(total_runners)):
    horse_name = driver.find_element_by_xpath(f"//div[@class='card-body']/div[{k+1}]/div/div[3]/div/div/h2/a")   
    print(horse_name.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-43-fe7b94bd3364> in <module>
#       1 total_runners = driver.find_element_by_xpath("//div[@class='race-header__details race-header__details--primary']/p[3]").text.split('-')[1].split(' ')[1]
#       2 for k in range(int(total_runners)):
# ----> 3     horse_name = driver.find_element_by_xpath(f"//div[@class='card-body']/div[{k+1}]/div/div[3]/div/div/h2/a")
#       4     print(horse_name.text)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     482         """
#     483         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 484         return self.find_element(by=By.XPATH, value=xpath)
#     485
#     486     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1151             value = '[name="%s"]' % value
#    1152
# -> 1153         return self.execute(Command.FIND_ELEMENT, {
#    1154             'using': by,
#    1155             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     398         response = self.command_executor.execute(driver_command, params)
#     399         if response:
# --> 400             self.error_handler.check_response(response)
#     401             response['value'] = self._unwrap_value(
#     402                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     234                 alert_text = value['alert'].get('text')
#     235             raise exception_class(message, screen, stacktrace, alert_text)
# --> 236         raise exception_class(message, screen, stacktrace)
#     237
#     238     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='card-body']/div[1]/div/div[3]/div/div/h2/a"}
#   (Session info: chrome=99.0.4844.74)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003C9943+2595139]
# 	Ordinal0 [0x0035C9F1+2148849]
# 	Ordinal0 [0x00254528+1066280]
# 	Ordinal0 [0x00280FD4+1249236]
# 	Ordinal0 [0x002811CB+1249739]
# 	Ordinal0 [0x002AD812+1431570]
# 	Ordinal0 [0x0029BA34+1358388]
# 	Ordinal0 [0x002ABAF2+1424114]
# 	Ordinal0 [0x0029B806+1357830]
# 	Ordinal0 [0x00276086+1204358]
# 	Ordinal0 [0x00276F96+1208214]
# 	GetHandleVerifier [0x0056B232+1658114]
# 	GetHandleVerifier [0x0062312C+2411516]
# 	GetHandleVerifier [0x0045F261+560433]
# 	GetHandleVerifier [0x0045E366+556598]
# 	Ordinal0 [0x0036286B+2173035]
# 	Ordinal0 [0x003675F8+2192888]
# 	Ordinal0 [0x003676E5+2193125]
# 	Ordinal0 [0x003711FC+2232828]
# 	BaseThreadInitThunk [0x762FFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77157A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77157A6E+238]

# %%
horse_name = driver.find_element_by_xpath(f"//div[@class='card-body']/div[3]/div/div[3]/div/div/h2/a")   
print(horse_name.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-44-9bbdcd350db3> in <module>
# ----> 1 horse_name = driver.find_element_by_xpath(f"//div[@class='card-body']/div[3]/div/div[3]/div/div/h2/a")
#       2 print(horse_name.text)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     482         """
#     483         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 484         return self.find_element(by=By.XPATH, value=xpath)
#     485
#     486     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1151             value = '[name="%s"]' % value
#    1152
# -> 1153         return self.execute(Command.FIND_ELEMENT, {
#    1154             'using': by,
#    1155             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     398         response = self.command_executor.execute(driver_command, params)
#     399         if response:
# --> 400             self.error_handler.check_response(response)
#     401             response['value'] = self._unwrap_value(
#     402                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     234                 alert_text = value['alert'].get('text')
#     235             raise exception_class(message, screen, stacktrace, alert_text)
# --> 236         raise exception_class(message, screen, stacktrace)
#     237
#     238     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='card-body']/div[3]/div/div[3]/div/div/h2/a"}
#   (Session info: chrome=99.0.4844.74)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003C9943+2595139]
# 	Ordinal0 [0x0035C9F1+2148849]
# 	Ordinal0 [0x00254528+1066280]
# 	Ordinal0 [0x00280FD4+1249236]
# 	Ordinal0 [0x002811CB+1249739]
# 	Ordinal0 [0x002AD812+1431570]
# 	Ordinal0 [0x0029BA34+1358388]
# 	Ordinal0 [0x002ABAF2+1424114]
# 	Ordinal0 [0x0029B806+1357830]
# 	Ordinal0 [0x00276086+1204358]
# 	Ordinal0 [0x00276F96+1208214]
# 	GetHandleVerifier [0x0056B232+1658114]
# 	GetHandleVerifier [0x0062312C+2411516]
# 	GetHandleVerifier [0x0045F261+560433]
# 	GetHandleVerifier [0x0045E366+556598]
# 	Ordinal0 [0x0036286B+2173035]
# 	Ordinal0 [0x003675F8+2192888]
# 	Ordinal0 [0x003676E5+2193125]
# 	Ordinal0 [0x003711FC+2232828]
# 	BaseThreadInitThunk [0x762FFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77157A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77157A6E+238]

# %%
race_time = driver.find_element_by_xpath("//h2[@class='h4 flush']/b").text
details1 = driver.find_element_by_xpath("//h2[@class='h4 flush']").text.split(' ')
racecourse_name = details1[1]
date = details1[2] + ' ' + details1[3] + ' ' + details1[4]
print(racecourse_name)
print(race_time)
print(date)
# Out:
# Lingfield
# 16:25
# 02 Mar 2022

# %%
horse_names = driver.find_elements_by_xpath("//h2[@class='h7 horse__details flush']/a")
print(len(horse_names))
for i in horse_names:
    print(i.text)
# Out:
# 18
# CAPRICORN PRINCE
# INDURO DE FONTAINE
# PLEDGE OF PEACE
# YORKTOWN
# MANDM
# LENNY'S SPIRIT
# DENABLE
# MISS POLLYANNA
# TILSWORTH SAMMY

# %%
race_courses = driver.find_elements_by_xpath("//div[@class='meetings-group reveal  ']/div/div/div/a")
for i in race_courses:
    print(i.get_attribute('href'))
# Out:
# https://www.attheraces.com/racecards/Cheltenham/16-March-2022
# https://www.attheraces.com/racecards/Cheltenham/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Huntingdon/16-March-2022
# https://www.attheraces.com/racecards/Huntingdon/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Kempton/16-March-2022
# https://www.attheraces.com/racecards/Kempton/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Newcastle/16-March-2022
# https://www.attheraces.com/racecards/Newcastle/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Chantilly/16-March-2022
# https://www.attheraces.com/racecards/Compiegne/16-March-2022
# https://www.attheraces.com/racecards/Enghien/16-March-2022
# https://www.attheraces.com/racecards/Durbanville/16-March-2022
# https://www.attheraces.com/racecards/Happy-Valley/16-March-2022
# https://www.attheraces.com/racecards/Sandown-Hillside/16-March-2022
# https://www.attheraces.com/racecards/Charles-Town/16-March-2022
# https://www.attheraces.com/racecards/Gulfstream/16-March-2022
# https://www.attheraces.com/racecards/Louisiana-Downs/16-March-2022
# https://www.attheraces.com/racecards/Mahoning-Valley/16-March-2022
# https://www.attheraces.com/racecards/Penn-National/16-March-2022
# https://www.attheraces.com/racecards/Sam-Houston-Race-Park/16-March-2022
# https://www.attheraces.com/racecards/Tampa-Bay-Downs/16-March-2022
# https://www.attheraces.com/racecards/Turf-Paradise/16-March-2022
# https://www.attheraces.com/racecards/Yonkers-Harness/16-March-2022
# https://www.attheraces.com/racecards/Cheltenham/16-March-2022
# https://www.attheraces.com/racecards/Cheltenham/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Huntingdon/16-March-2022
# https://www.attheraces.com/racecards/Huntingdon/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Kempton/16-March-2022
# https://www.attheraces.com/racecards/Kempton/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Newcastle/16-March-2022
# https://www.attheraces.com/racecards/Newcastle/16-March-2022/SmartStats
# https://www.attheraces.com/racecards/Chantilly/16-March-2022
# https://www.attheraces.com/racecards/Compiegne/16-March-2022
# https://www.attheraces.com/racecards/Enghien/16-March-2022
# https://www.attheraces.com/racecards/Durbanville/16-March-2022
# https://www.attheraces.com/racecards/Happy-Valley/16-March-2022
# https://www.attheraces.com/racecards/Sandown-Hillside/16-March-2022
# https://www.attheraces.com/racecards/Charles-Town/16-March-2022
# https://www.attheraces.com/racecards/Gulfstream/16-March-2022
# https://www.attheraces.com/racecards/Louisiana-Downs/16-March-2022
# https://www.attheraces.com/racecards/Mahoning-Valley/16-March-2022
# https://www.attheraces.com/racecards/Penn-National/16-March-2022
# https://www.attheraces.com/racecards/Sam-Houston-Race-Park/16-March-2022
# https://www.attheraces.com/racecards/Tampa-Bay-Downs/16-March-2022
# https://www.attheraces.com/racecards/Turf-Paradise/16-March-2022
# https://www.attheraces.com/racecards/Yonkers-Harness/16-March-2022

# %%
element_to_hover_over = driver.find_element_by_xpath('//input[@id="race-nav-datepicker"]')
ActionChains(driver).move_to_element(element_to_hover_over).perform()

ele = driver.find_elements_by_xpath('//div[@id="tab-race-nav--uk"]/div/div/div/div/div/label/span[@class="meetings-group__title"]')
for i in ele:
    print(i.text)
